# %% [markdown]
# <a href="https://colab.research.google.com/github/duttagoutam/AIML/blob/master/AutomaticImageCaptioning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/

# %%
import numpy as np
from numpy import array
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import string
import os
from PIL import Image
import glob
import pickle
from pickle import dump, load
from time import time
from keras.preprocessing import sequence
from keras.models import Sequential
from keras.layers import LSTM, Embedding, TimeDistributed, Dense, RepeatVector,\
                         Activation, Flatten, Reshape, concatenate, Dropout, BatchNormalization
from keras.optimizers import Adam, RMSprop
from keras.layers.wrappers import Bidirectional
from keras.layers.merge import add
from keras.applications.inception_v3 import InceptionV3
from keras.preprocessing import image
from keras.models import Model
from keras import Input, layers
from keras import optimizers
from keras.applications.inception_v3 import preprocess_input
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical
from sklearn import metrics
from nltk.translate.bleu_score import corpus_bleu
# Out:
# Using TensorFlow backend.

# %%
folderName='/content/drive/My Drive/App/storage/Flickr8k_Dataset'
imageDir=folderName+'/Images'

# %%
# load doc into memory
def load_doc(filename):
	# open the file as read only
	file = open(filename, 'r')
	# read all text
	text = file.read()
	# close the file
	file.close()
	return text

filename = folderName+"/Flickr_TextData/Flickr8k.token.txt"
# load descriptions
doc = load_doc(filename)
print(doc[:300])
# Out:
# 1000268201_693b08cb0e.jpg#0	A child in a pink dress is climbing up a set of stairs in an entry way .
# 1000268201_693b08cb0e.jpg#1	A girl going into a wooden building .
# 1000268201_693b08cb0e.jpg#2	A little girl climbing into a wooden playhouse .
# 1000268201_693b08cb0e.jpg#3	A little girl climbing the s

# %%
def load_descriptions(doc):
	mapping = dict()
	# process lines
	for line in doc.split('\n'):
		# split line by white space
		tokens = line.split()
		if len(line) < 2:
			continue
		# take the first token as the image id, the rest as the description
		image_id, image_desc = tokens[0], tokens[1:]
		# extract filename from image id
		image_id = image_id.split('.')[0]
		# convert description tokens back to string
		image_desc = ' '.join(image_desc)
		# create the list if needed
		if image_id not in mapping:
			mapping[image_id] = list()
		# store description
		mapping[image_id].append(image_desc)
	return mapping

# parse descriptions
descriptions = load_descriptions(doc)
print('Loaded: %d ' % len(descriptions))
# Out:
# Loaded: 8091

# %%
list(descriptions.keys())[:5]
# Out:
# ['1000268201_693b08cb0e',
#  '1001773457_577c3a7d70',
#  '1002674143_1b742ab4b8',
#  '1003163366_44323f5815',
#  '1007129816_e794419615']

# %%
descriptions['1000268201_693b08cb0e']
# Out:
# ['A child in a pink dress is climbing up a set of stairs in an entry way .',
#  'A girl going into a wooden building .',
#  'A little girl climbing into a wooden playhouse .',
#  'A little girl climbing the stairs to her playhouse .',
#  'A little girl in a pink dress going into a wooden cabin .']

# %%
descriptions['1001773457_577c3a7d70']
# Out:
# ['A black dog and a spotted dog are fighting',
#  'A black dog and a tri-colored dog playing with each other on the road .',
#  'A black dog and a white dog with brown spots are staring at each other in the street .',
#  'Two dogs of different breeds looking at each other on the road .',
#  'Two dogs on pavement moving toward each other .']

# %%
def clean_descriptions(descriptions):
	# prepare translation table for removing punctuation
	table = str.maketrans('', '', string.punctuation)
	for key, desc_list in descriptions.items():
		for i in range(len(desc_list)):
			desc = desc_list[i]
			# tokenize
			desc = desc.split()
			# convert to lower case
			desc = [word.lower() for word in desc]
			# remove punctuation from each token
			desc = [w.translate(table) for w in desc]
			# remove hanging 's' and 'a'
			desc = [word for word in desc if len(word)>1]
			# remove tokens with numbers in them
			desc = [word for word in desc if word.isalpha()]
			# store as string
			desc_list[i] =  ' '.join(desc)

# clean descriptions
clean_descriptions(descriptions)

# %%
descriptions['1000268201_693b08cb0e']
# Out:
# ['child in pink dress is climbing up set of stairs in an entry way',
#  'girl going into wooden building',
#  'little girl climbing into wooden playhouse',
#  'little girl climbing the stairs to her playhouse',
#  'little girl in pink dress going into wooden cabin']

# %%
descriptions['1001773457_577c3a7d70']
# Out:
# ['black dog and spotted dog are fighting',
#  'black dog and tricolored dog playing with each other on the road',
#  'black dog and white dog with brown spots are staring at each other in the street',
#  'two dogs of different breeds looking at each other on the road',
#  'two dogs on pavement moving toward each other']

# %%
# convert the loaded descriptions into a vocabulary of words
def to_vocabulary(descriptions):
	# build a list of all description strings
	all_desc = set()
	for key in descriptions.keys():
		[all_desc.update(d.split()) for d in descriptions[key]]
	return all_desc

# summarize vocabulary
vocabulary = to_vocabulary(descriptions)
print('Original Vocabulary Size: %d' % len(vocabulary))
# Out:
# Original Vocabulary Size: 8763

# %%
# save descriptions to file, one per line
def save_descriptions(descriptions, filename):
	lines = list()
	for key, desc_list in descriptions.items():
		for desc in desc_list:
			lines.append(key + ' ' + desc)
	data = '\n'.join(lines)
	file = open(filename, 'w')
	file.write(data)
	file.close()

save_descriptions(descriptions, folderName+'/descriptions.txt')

# %%
# load a pre-defined list of photo identifiers
def load_set(filename):
	doc = load_doc(filename)
	dataset = list()
	# process line by line
	for line in doc.split('\n'):
		# skip empty lines
		if len(line) < 1:
			continue
		# get the image identifier
		identifier = line.split('.')[0]
		dataset.append(identifier)
	return set(dataset)

# load training dataset (6K)
filename = folderName+"/Flickr_TextData/Flickr_8k.trainImages.txt"
train = load_set(filename)
print('Train Dataset: %d' % len(train))

# load test dataset (1K)
testfile = folderName+"/Flickr_TextData/Flickr_8k.testImages.txt"
test = load_set(testfile)
print('Test Dataset: %d' % len(test))
# Out:
# Train Dataset: 6000
# Test Dataset: 1000

# %%
# Below path contains all the images
#images = '../../storage/image_caption/dataset/Flicker8k_Dataset/'
images = folderName+'/Images/'
print('images: %s' % images)
# Create a list of all image names in the directory
img = glob.glob(images + '*.jpg')
print('img: %d' % len(img))
# Out:
# images: /content/drive/My Drive/App/storage/Flickr8k_Dataset/Images/
# img: 8099

# %%
# Below file conatains the names of images to be used in train data
train_images_file = folderName+"/Flickr_TextData/Flickr_8k.trainImages.txt"
# Read the train image names in a set
train_images = set(open(train_images_file, 'r').read().strip().split('\n'))
print('train_images: %d' % len(train_images))
# Create a list of all the training images with their full path names
train_img = []
print(len(images))
for i in img: # img is list of full path names of all images
    if i[len(images):] in train_images: # Check if the image belongs to training set
        train_img.append(i) # Add it to the list of train images

print('train_img: %d' % len(train_img))
# Out:
# train_images: 6000
# 60
# train_img: 6000

# %%
# Below file conatains the names of images to be used in test data
test_images_file = folderName+"/Flickr_TextData/Flickr_8k.testImages.txt"
# Read the validation image names in a set# Read the test image names in a set
test_images = set(open(test_images_file, 'r').read().strip().split('\n'))
print('test_images: %d' % len(test_images))
# Create a list of all the test images with their full path names
test_img = []

for i in img: # img is list of full path names of all images
    if i[len(images):] in test_images: # Check if the image belongs to test set
        test_img.append(i) # Add it to the list of test images

print('test_img: %d' % len(test_img))
# Out:
# test_images: 1000
# test_img: 1000

# %%
# load clean descriptions into memory
def load_clean_descriptions(filename, dataset):
	# load document
	doc = load_doc(filename)
	descriptions = dict()
	for line in doc.split('\n'):
		# split line by white space
		tokens = line.split()
		# split id from description
		image_id, image_desc = tokens[0], tokens[1:]
		# skip images not in the set
		if image_id in dataset:
			# create list
			if image_id not in descriptions:
				descriptions[image_id] = list()
			# wrap description in tokens
			desc = 'startseq ' + ' '.join(image_desc) + ' endseq'
			# store
			descriptions[image_id].append(desc)
	return descriptions

# descriptions
train_descriptions = load_clean_descriptions(folderName+'/descriptions.txt', train)
print('Train Descriptions: train=%d' % len(train_descriptions))

# descriptions
test_descriptions = load_clean_descriptions(folderName+'/descriptions.txt', test)
print('Test Descriptions: train=%d' % len(test_descriptions))
# Out:
# Train Descriptions: train=6000
# Test Descriptions: train=1000

# %%
def preprocess(image_path):
    # Convert all the images to size 299x299 as expected by the inception v3 model
    img = image.load_img(image_path, target_size=(299, 299))
    # Convert PIL image to numpy array of 3-dimensions
    x = image.img_to_array(img)
    # Add one more dimension
    x = np.expand_dims(x, axis=0)
    # preprocess the images using preprocess_input() from inception module
    x = preprocess_input(x)
    return x

# %%
# Load the inception v3 model
model = InceptionV3(weights='imagenet')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:203: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2041: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4271: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.5/inception_v3_weights_tf_dim_ordering_tf_kernels.h5
# 96116736/96112376 [==============================] - 2s 0us/step

# %%
# Create a new model, by removing the last layer (output layer) from the inception v3
model_new = Model(model.input, model.layers[-2].output)

# %%
# Function to encode a given image into a vector of size (2048, )
def encode(image):
    image = preprocess(image) # preprocess the image
    fea_vec = model_new.predict(image) # Get the encoding vector for the image
    fea_vec = np.reshape(fea_vec, fea_vec.shape[1]) # reshape from (1, 2048) to (2048, )
    return fea_vec

# %%
# Call the funtion to encode all the train images
# This will take a while on CPU - Execute this only once

start = time()
encoding_train = {}
for img in train_img:
    encoding_train[img[len(images):]] = encode(img)
print("Time taken in seconds =", time()-start)
# Out:
# Time taken in seconds = 3940.550678730011

# %%
import pickle
# Save the bottleneck train features to disk
with open(folderName+"/encoded_train_images.pkl", "wb") as encoded_pickle:
    pickle.dump(encoding_train, encoded_pickle)

# %%
# Call the funtion to encode all the test images - Execute this only once
start = time()
encoding_test = {}
for img in test_img:
    encoding_test[img[len(images):]] = encode(img)
print("Time taken in seconds =", time()-start)
# Out:
# Time taken in seconds = 663.5420525074005

# %%
# Save the bottleneck test features to disk
with open(folderName+"/encoded_test_images.pkl", "wb") as encoded_pickle:
    pickle.dump(encoding_test, encoded_pickle)

# %%
train_features = load(open(folderName+"/encoded_train_images.pkl", "rb"))
print('Photos: train=%d' % len(train_features))
# Out:
# Photos: train=6000

# %%
test_features = load(open(folderName+"/encoded_test_images.pkl", "rb"))
print('Photos: test=%d' % len(test_features))
# Out:
# Photos: test=1000

# %%
# Create a list of all the training captions
all_train_captions = []
for key, val in train_descriptions.items():
    for cap in val:
        all_train_captions.append(cap)
len(all_train_captions)
# Out:
# 30000

# %%
# Consider only words which occur at least 10 times in the corpus
word_count_threshold = 10
word_counts = {}
nsents = 0
for sent in all_train_captions:
    nsents += 1
    for w in sent.split(' '):
        word_counts[w] = word_counts.get(w, 0) + 1

vocab = [w for w in word_counts if word_counts[w] >= word_count_threshold]
print('preprocessed words %d -> %d' % (len(word_counts), len(vocab)))
# Out:
# preprocessed words 7578 -> 1651

# %%
ixtoword = {}
wordtoix = {}

ix = 1
for w in vocab:
    wordtoix[w] = ix
    ixtoword[ix] = w
    ix += 1

# %%
vocab_size = len(ixtoword) + 1 # one for appended 0's
vocab_size
# Out:
# 1652

# %%
# convert a dictionary of clean descriptions to a list of descriptions
def to_lines(descriptions):
	all_desc = list()
	for key in descriptions.keys():
		[all_desc.append(d) for d in descriptions[key]]
	return all_desc

# calculate the length of the description with the most words
def max_length(descriptions):
	lines = to_lines(descriptions)
	return max(len(d.split()) for d in lines)

# determine the maximum sequence length
max_length = max_length(train_descriptions)
print('Description Length: %d' % max_length)
# Out:
# Description Length: 34

# %%
# data generator, intended to be used in a call to model.fit_generator()
def data_generator(descriptions, photos, wordtoix, max_length, num_photos_per_batch):
    X1, X2, y = list(), list(), list()
    n=0
    # loop for ever over images
    while 1:
        for key, desc_list in descriptions.items():
            n+=1
            # retrieve the photo feature
            photo = photos[key+'.jpg']
            for desc in desc_list:
                # encode the sequence
                seq = [wordtoix[word] for word in desc.split(' ') if word in wordtoix]
                # split one sequence into multiple X, y pairs
                for i in range(1, len(seq)):
                    # split into input and output pair
                    in_seq, out_seq = seq[:i], seq[i]
                    # pad input sequence
                    in_seq = pad_sequences([in_seq], maxlen=max_length)[0]
                    # encode output sequence
                    out_seq = to_categorical([out_seq], num_classes=vocab_size)[0]
                    # store
                    X1.append(photo)
                    X2.append(in_seq)
                    y.append(out_seq)
            # yield the batch data
            if n==num_photos_per_batch:
                yield [[array(X1), array(X2)], array(y)]
                X1, X2, y = list(), list(), list()
                n=0

# %%
# Load Glove vectors
# glove_dir = '../../storage/glove'
glove_dir = folderName+"/Flickr_TextData/"
embeddings_index = {} # empty dictionary
f = open(os.path.join(glove_dir, 'glove.6B.200d.txt'), encoding="utf-8")

for line in f:
    values = line.split()
    word = values[0]
    coefs = np.asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs
f.close()
print('Found %s word vectors.' % len(embeddings_index))
# Out:
# Found 400000 word vectors.

# %%
embedding_dim = 200

# Get 200-dim dense vector for each of the 10000 words in out vocabulary
embedding_matrix = np.zeros((vocab_size, embedding_dim))

for word, i in wordtoix.items():
    #if i < max_words:
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        # Words not found in the embedding index will be all zeros
        embedding_matrix[i] = embedding_vector

# %%
embedding_matrix.shape
# Out:
# (1652, 200)

# %%
inputs1 = Input(shape=(2048,))
fe1 = Dropout(0.5)(inputs1)
fe2 = Dense(256, activation='relu')(fe1)
inputs2 = Input(shape=(max_length,))
se1 = Embedding(vocab_size, embedding_dim, mask_zero=True)(inputs2)
se2 = Dropout(0.5)(se1)
se3 = LSTM(256)(se2)
decoder1 = add([fe2, se3])
decoder2 = Dense(256, activation='relu')(decoder1)
outputs = Dense(vocab_size, activation='softmax')(decoder2)
model = Model(inputs=[inputs1, inputs2], outputs=outputs)

# %%
model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            (None, 34)           0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            (None, 2048)         0
# __________________________________________________________________________________________________
# embedding_2 (Embedding)         (None, 34, 200)      330400      input_5[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 2048)         0           input_4[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 34, 200)      0           embedding_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 256)          524544      dropout_3[0][0]
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   (None, 256)          467968      dropout_4[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 256)          0           dense_4[0][0]
#                                                                  lstm_2[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 256)          65792       add_2[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 1652)         424564      dense_5[0][0]
# ==================================================================================================
# Total params: 1,813,268
# Trainable params: 1,813,268
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.layers[2]

# %%
model.layers[2].set_weights([embedding_matrix])
model.layers[2].trainable = False

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3576: The name tf.log is deprecated. Please use tf.math.log instead.

# %%
epochs = 10
number_pics_per_bath = 3
steps = len(train_descriptions)//number_pics_per_bath

# %%
for i in range(epochs):
    generator = data_generator(train_descriptions, train_features, wordtoix, max_length, number_pics_per_bath)
    model.fit_generator(generator, epochs=1, steps_per_epoch=steps, verbose=1)
    #model.save('./model_weights/model_' + str(i) + '.h5')
# Out:
# Epoch 1/1
# 2000/2000 [==============================] - 134s 67ms/step - loss: 4.1161
# Epoch 1/1
# 2000/2000 [==============================] - 131s 65ms/step - loss: 3.4084
# Epoch 1/1
# 2000/2000 [==============================] - 121s 60ms/step - loss: 3.1949
# Epoch 1/1
# 2000/2000 [==============================] - 122s 61ms/step - loss: 3.0587
# Epoch 1/1
# 2000/2000 [==============================] - 118s 59ms/step - loss: 2.9650
# Epoch 1/1
# 2000/2000 [==============================] - 119s 59ms/step - loss: 2.8900
# Epoch 1/1
# 2000/2000 [==============================] - 118s 59ms/step - loss: 2.8345
# Epoch 1/1
# 2000/2000 [==============================] - 118s 59ms/step - loss: 2.7878
# Epoch 1/1
# 2000/2000 [==============================] - 118s 59ms/step - loss: 2.7484
# Epoch 1/1
# 2000/2000 [==============================] - 118s 59ms/step - loss: 2.7090

# %%
for i in range(epochs):
    generator = data_generator(train_descriptions, train_features, wordtoix, max_length, number_pics_per_bath)
    model.fit_generator(generator, epochs=1, steps_per_epoch=steps, verbose=1)
    model.save('./model_weights/model_' + str(i) + '.h5')
# Out:
# Epoch 1/1
# 2000/2000 [==============================] - 118s 59ms/step - loss: 2.6823
# Epoch 1/1
# 2000/2000 [==============================] - 118s 59ms/step - loss: 2.6567
# Epoch 1/1
# 2000/2000 [==============================] - 118s 59ms/step - loss: 2.6342
# Epoch 1/1
# 2000/2000 [==============================] - 118s 59ms/step - loss: 2.6129
# Epoch 1/1
# 2000/2000 [==============================] - 118s 59ms/step - loss: 2.5916
# Epoch 1/1
# 2000/2000 [==============================] - 118s 59ms/step - loss: 2.5761
# Epoch 1/1
# 2000/2000 [==============================] - 118s 59ms/step - loss: 2.5610
# Epoch 1/1
# 2000/2000 [==============================] - 118s 59ms/step - loss: 2.5488
# Epoch 1/1
# 2000/2000 [==============================] - 118s 59ms/step - loss: 2.5363
# Epoch 1/1
# 2000/2000 [==============================] - 118s 59ms/step - loss: 2.5255

# %%
model.optimizer.lr = 0.0001
epochs = 10
number_pics_per_bath = 6
steps = len(train_descriptions)//number_pics_per_bath

# %%
for i in range(epochs):
    generator = data_generator(train_descriptions, train_features, wordtoix, max_length, number_pics_per_bath)
    model.fit_generator(generator, epochs=1, steps_per_epoch=steps, verbose=1)
    #model.save('./model_weights/model_' + str(i) + '.h5')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Epoch 1/1
# 1000/1000 [==============================] - 754s 754ms/step - loss: 5.1461
# Epoch 1/1
# 1000/1000 [==============================] - 749s 749ms/step - loss: 4.4219
# Epoch 1/1
# 1000/1000 [==============================] - 750s 750ms/step - loss: 4.0700
# Epoch 1/1
# 1000/1000 [==============================] - 747s 747ms/step - loss: 3.8722
# Epoch 1/1
# 1000/1000 [==============================] - 751s 751ms/step - loss: 3.7384
# Epoch 1/1
# 1000/1000 [==============================] - 753s 753ms/step - loss: 3.6374
# Epoch 1/1
# 1000/1000 [==============================] - 750s 750ms/step - loss: 3.5530
# Epoch 1/1
# 1000/1000 [==============================] - 752s 752ms/step - loss: 3.4840
# Epoch 1/1
# 1000/1000 [==============================] - 754s 754ms/step - loss: 3.4240
# Epoch 1/1
# 1000/1000 [==============================] - 755s 755ms/step - loss: 3.3723

# %%
#model.save_weights('./model_weights/model_30.h5')
model.save_weights(folderName+'/'+'model_30.h5')

# %%
model.load_weights(folderName+'/model_30.h5')

# %%
#images = '../../storage/image_caption/dataset/Flicker8k_Dataset/'
images =imageDir+'/'

# %%
with open(folderName+"/encoded_test_images.pkl", "rb") as encoded_pickle:
    encoding_test = load(encoded_pickle)

# %%
def greedySearch(photo):
    in_text = 'startseq'
    for i in range(max_length):
        sequence = [wordtoix[w] for w in in_text.split() if w in wordtoix]
        sequence = pad_sequences([sequence], maxlen=max_length)
        yhat = model.predict([photo,sequence], verbose=0)
        yhat = np.argmax(yhat)
        word = ixtoword[yhat]
        in_text += ' ' + word
        if word == 'endseq':
            break
    final = in_text.split()
    final = final[1:-1]
    final = ' '.join(final)
    return final

# %%
from nltk.translate.bleu_score import corpus_bleu
beluscores = []
# evaluate the skill of the model
def evaluate_model(testdescriptionstext, predictiontext):
	actual, predicted = list(), list()
	# step over the whole set
	#for key, desc in testdescriptionstext.items():
	for desc in testdescriptionstext:
		# generate description
		#yhat = generate_desc(model, tokenizer, photos[key], max_length)
		# store actual and predicted
		#actual.append([desc.split()])
		references = [d.split() for d in desc]
		#references = testdescriptionstext[i]
		actual.append(references)
		predicted.append(predictiontext)
		#print('Actual:    %s' % desc)
		#print('Predicted: %s' % predictiontext)
		# calculate BLEU score
		bleu = corpus_bleu(actual, predicted)
		print("bleu_score:",bleu)
		beluscores.append(bleu)
	return bleu

# %%
print(len(encoding_test))
# Out:
# 1000

# %%
z=1
pic = list(encoding_test.keys())[z]
#print(pic)
name = pic.strip('.jpg')
#print(name)
#print(test_descriptions[name])
image = encoding_test[pic].reshape((1,2048))
#print(image)
x=plt.imread(images+pic)
plt.imshow(x)
plt.show()
predicted = greedySearch(image)
print("Greedy:",predicted)
# evaluate model
bleu_score = evaluate_model(test_descriptions[name], predicted)
print("final bleu_score:",bleu_score)
# Out:
# ['startseq brown dog about to jump on smaller black and tan dog endseq', 'startseq large dog playing with smaller dog endseq', 'startseq two dogs are playing together outside endseq', 'startseq two dogs playing in the grass with an adult nearby endseq', 'startseq two dogs playing with each other endseq']
# Greedy: two dogs are running through the grass
# bleu_score: 0.733503637924837
# bleu_score: 0.7417004814749555
# bleu_score: 0.749634235443537
# bleu_score: 0.7535084431893706
# bleu_score: 0.752738377346319
# final bleu_score: 0.752738377346319
# /usr/local/lib/python3.6/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 2-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)

# %%
# descriptions
train_descriptions = load_clean_descriptions(folderName+'/descriptions.txt', train)
print('Train Descriptions: train=%d' % len(train_descriptions))

# descriptions
test_descriptions = load_clean_descriptions(folderName+'/descriptions.txt', test)
print('Test Descriptions: train=%d' % len(test_descriptions))
# Out:
# Train Descriptions: train=6000
# Test Descriptions: train=1000

# %%
generator = data_generator(train_descriptions, train_features, wordtoix, max_length, number_pics_per_bath)
history_learning = model.fit_generator(generator, epochs=1, steps_per_epoch=steps, verbose=1)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Epoch 1/1
# 1000/1000 [==============================] - 764s 764ms/step - loss: 5.1481 - acc: 0.1577

# %%
plt.plot(history_learning.history['acc'])
plt.plot(history_learning.history['loss'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('loss')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(history_learning.history['accuracy'])
plt.plot(history_learning.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-60-5163143829ac> in <module>()
# ----> 1 plt.plot(history_learning.history['accuracy'])
#       2 plt.plot(history_learning.history['val_accuracy'])
#       3 plt.title('model accuracy')
#       4 plt.ylabel('accuracy')
#       5 plt.xlabel('epoch')
#
# KeyError: 'accuracy'

# %%
for label in ["loss","val_loss"]:
    plt.plot(history_learning.history[label],label=label)
plt.legend()
plt.xlabel("epochs")
plt.ylabel("loss")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-61-30b35313365d> in <module>()
#       1 for label in ["loss","val_loss"]:
# ----> 2     plt.plot(history_learning.history[label],label=label)
#       3 plt.legend()
#       4 plt.xlabel("epochs")
#       5 plt.ylabel("loss")
#
# KeyError: 'val_loss'

# %%
for z,item in enumerate(encoding_test) :
    pic = list(encoding_test.keys())[z]
    #print(pic)
    name = pic.strip('.jpg')
    #print(name)
    #print(test_descriptions[name])
    image = encoding_test[pic].reshape((1,2048))
    #print(image)
    #x=plt.imread(images+pic)
    #plt.imshow(x)
    #plt.show()
    predicted = greedySearch(image)
    print("Greedy:",predicted)
    # evaluate model
    evaluate_model(test_descriptions[name], predicted)
    #print("final bleu_score:",bleu_score)
    #beluscores.append(bleu_score)
# Out:
# Greedy: dog runs through the snow
# bleu_score: 0.8144476398584994
# bleu_score: 0.8144476398584994
# bleu_score: 0.8144476398584994
# bleu_score: 0.8097801259787746
# bleu_score: 0.8107200928842206
# Greedy: two dogs are running through the grass
# bleu_score: 0.733503637924837
# bleu_score: 0.7417004814749555
# bleu_score: 0.749634235443537
# bleu_score: 0.7535084431893706
# bleu_score: 0.752738377346319
# /usr/local/lib/python3.6/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 2-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)
# Greedy: two women in red dresses are standing on the sidewalk
# bleu_score: 0.7037475090852178
# bleu_score: 0.6968808586685619
# bleu_score: 0.7037475090852178
# bleu_score: 0.7071067811865476
# bleu_score: 0.7090995866113936
# Greedy: man is walking on rocky beach
# bleu_score: 0.7847813466510527
# bleu_score: 0.8182506116172393
# bleu_score: 0.8234461145823753
# bleu_score: 0.8221564534369494
# bleu_score: 0.8275328213032681
# Greedy: man in red jacket is walking down snowy hill
# bleu_score: 0.7510499815709779
# bleu_score: 0.7372633901833245
# bleu_score: 0.7465389668481563
# bleu_score: 0.7476743906106103
# bleu_score: 0.7510499815709779
# Greedy: little boy is blowing on the playground
# bleu_score: 0.8003203203844999
# bleu_score: 0.8003203203844999
# bleu_score: 0.8003203203844999
# bleu_score: 0.8003203203844999
# bleu_score: 0.7952707287670506
# Greedy: two dogs are playing in the grass
# bleu_score: 0.7598356856515925
# bleu_score: 0.7765453555044466
# bleu_score: 0.7871130275822675
# bleu_score: 0.7922410709252884
# bleu_score: 0.7952707287670506
# Greedy: man in red hat and hat and hat hat and hat
# bleu_score: 0.6606328636027614
# bleu_score: 0.6707217794445165
# bleu_score: 0.6739857287654524
# bleu_score: 0.6657346545088059
# bleu_score: 0.664723665025
# Greedy: woman in red shirt is standing in front of building
# bleu_score: 0.7598356856515925
# bleu_score: 0.748406329216425
# bleu_score: 0.7364279629037999
# bleu_score: 0.7394774192785843
# bleu_score: 0.7388705435772311
# Greedy: man wearing helmet is standing on the snow
# bleu_score: 0.7153784423080968
# bleu_score: 0.7153784423080968
# bleu_score: 0.7311104457090247
# bleu_score: 0.7348889200874658
# bleu_score: 0.7371283231463883
# Greedy: white dog is running through the grass
# bleu_score: 0.7647860170437231
# bleu_score: 0.7647860170437231
# bleu_score: 0.7647860170437231
# bleu_score: 0.7647860170437231
# bleu_score: 0.7647860170437231
# Greedy: man climbing rock rock
# bleu_score: 0.8408964152537145
# bleu_score: 0.8408964152537145
# bleu_score: 0.8344522897223012
# bleu_score: 0.8360773262202078
# bleu_score: 0.8251717906224465
# Greedy: group of people are standing on the street
# bleu_score: 0.7598356856515925
# bleu_score: 0.7665309200501981
# bleu_score: 0.7687241639790432
# bleu_score: 0.7632053278841269
# bleu_score: 0.7625349668264003
# Greedy: group of people are standing in front of crowd
# bleu_score: 0.7427498127683173
# bleu_score: 0.7427498127683173
# bleu_score: 0.7427498127683173
# bleu_score: 0.7460436843047203
# bleu_score: 0.7427498127683173
# Greedy: child in red shirt is standing on the snow
# bleu_score: 0.7458878201607712
# bleu_score: 0.7458878201607712
# bleu_score: 0.7506238537503395
# bleu_score: 0.7529586373193689
# bleu_score: 0.7515603794065152
# Greedy: man in black shirt and black shirt and black hat is standing in front of building
# bleu_score: 0.6666666666666666
# bleu_score: 0.6504602262101259
# bleu_score: 0.6559965570884768
# bleu_score: 0.6587129570401602
# bleu_score: 0.6581723632676225
# Greedy: dog runs through the woods
# bleu_score: 0.7670387248467655
# bleu_score: 0.7875110621102679
# bleu_score: 0.7939931813032876
# bleu_score: 0.7971755824799469
# bleu_score: 0.7914194256246622
# Greedy: two women in costumes are standing in front of
# bleu_score: 0.7291155827927387
# bleu_score: 0.7360274036243225
# bleu_score: 0.7337451206367
# bleu_score: 0.7360274036243225
# bleu_score: 0.7373866474625921
# Greedy: dog runs through the grass
# bleu_score: 0.8065008590125561
# bleu_score: 0.7971755824799469
# bleu_score: 0.7939931813032876
# bleu_score: 0.7971755824799469
# bleu_score: 0.7952707287670506
# Greedy: two dogs are playing in field
# bleu_score: 0.8480536257973762
# bleu_score: 0.8335516383402117
# bleu_score: 0.8335516383402117
# bleu_score: 0.8298052440330109
# bleu_score: 0.8335516383402117
# Greedy: boy in red shirt is standing on the sidewalk
# bleu_score: 0.7226568811456053
# bleu_score: 0.7300697164579737
# bleu_score: 0.7419446627365011
# bleu_score: 0.7372633901833245
# bleu_score: 0.7315254958027826
# Greedy: two people are walking on sidewalk
# bleu_score: 0.8010548969451144
# bleu_score: 0.7863503941633413
# bleu_score: 0.7863503941633413
# bleu_score: 0.79010396331546
# bleu_score: 0.7893575251055271
# Greedy: man in red shirt and jeans is walking down sidewalk
# bleu_score: 0.6964705665515708
# bleu_score: 0.6964705665515708
# bleu_score: 0.7012575875367208
# bleu_score: 0.7036147891341804
# bleu_score: 0.7077990059813023
# Greedy: man is walking on the beach
# bleu_score: 0.8633400213704505
# bleu_score: 0.8560538001743465
# bleu_score: 0.8485766316739435
# bleu_score: 0.8408964152537145
# bleu_score: 0.8361853256187297
# Greedy: child is sitting on the top of the slide
# bleu_score: 0.7400828044922853
# bleu_score: 0.7400828044922853
# bleu_score: 0.7400828044922853
# bleu_score: 0.7322501380936575
# bleu_score: 0.7306530726696259
# Greedy: two men are walking down the street
# bleu_score: 0.8091067115702212
# bleu_score: 0.8091067115702212
# bleu_score: 0.7904941119584155
# bleu_score: 0.7916963878457504
# bleu_score: 0.7924151324695536
# Greedy: man in white shirt is walking on the grass
# bleu_score: 0.6803749333171202
# bleu_score: 0.7071067811865476
# bleu_score: 0.7098962112020106
# bleu_score: 0.719408902854813
# bleu_score: 0.7217950347929304
# Greedy: two dogs are playing with ball
# bleu_score: 0.8408964152537145
# bleu_score: 0.8408964152537145
# bleu_score: 0.8408964152537145
# bleu_score: 0.8373705664750549
# bleu_score: 0.8380793022482116
# Greedy: man in red shirt is standing on the sidewalk
# bleu_score: 0.7372633901833245
# bleu_score: 0.7442524500510544
# bleu_score: 0.7465389668481563
# bleu_score: 0.7476743906106103
# bleu_score: 0.7483531696941793
# Greedy: two young boys are sitting on the grass
# bleu_score: 0.6930977286178778
# bleu_score: 0.7025297977970931
# bleu_score: 0.7115965735877551
# bleu_score: 0.7071067811865476
# bleu_score: 0.7151281786901973
# Greedy: dog is jumping over the grass
# bleu_score: 0.8335516383402117
# bleu_score: 0.8102667241708824
# bleu_score: 0.8182506116172393
# bleu_score: 0.8182506116172393
# bleu_score: 0.8150851727457197
# Greedy: man is climbing rock
# bleu_score: 0.81903625881272
# bleu_score: 0.8408964152537145
# bleu_score: 0.8337996085114259
# bleu_score: 0.8461034529913098
# bleu_score: 0.8532355998949246
# Greedy: man in red shirt is walking on street
# bleu_score: 0.7979439453790055
# bleu_score: 0.7979439453790055
# bleu_score: 0.7979439453790055
# bleu_score: 0.7945981947797423
# bleu_score: 0.7898419423479888
# Greedy: young boy is jumping over the air
# bleu_score: 0.7922410709252884
# bleu_score: 0.7510499815709779
# bleu_score: 0.7540127609098941
# bleu_score: 0.7554811471453416
# bleu_score: 0.7598356856515925
# Greedy: man is climbing rock rock
# bleu_score: 0.8144476398584994
# bleu_score: 0.8235490260528069
# bleu_score: 0.8265168183793802
# bleu_score: 0.81903625881272
# bleu_score: 0.8181246978470094
# Greedy: woman in red shirt and black hat stands on the sidewalk
# bleu_score: 0.7102992180127422
# bleu_score: 0.7165579655913892
# bleu_score: 0.7102992180127422
# bleu_score: 0.7165579655913892
# bleu_score: 0.7102992180127422
# Greedy: two dogs are playing in field
# bleu_score: 0.8182506116172393
# bleu_score: 0.8102667241708824
# bleu_score: 0.8129542128873352
# bleu_score: 0.8142880224789865
# bleu_score: 0.8086413063091928
# Greedy: dog is running through the grass
# bleu_score: 0.7476743906106103
# bleu_score: 0.7657035784021965
# bleu_score: 0.7657035784021965
# bleu_score: 0.7700175720602557
# bleu_score: 0.7691605673134586
# Greedy: two people are sitting on the street
# bleu_score: 0.7598356856515925
# bleu_score: 0.7598356856515925
# bleu_score: 0.7598356856515925
# bleu_score: 0.7598356856515925
# bleu_score: 0.7598356856515925
# Greedy: two people are walking down the edge of the water
# bleu_score: 0.7438301789874407
# bleu_score: 0.7375525698389189
# bleu_score: 0.7222468628919761
# bleu_score: 0.7278244729081154
# bleu_score: 0.7258313246514702
# Greedy: two people are standing on the beach
# bleu_score: 0.816496580927726
# bleu_score: 0.8034284189446518
# bleu_score: 0.8078551893223442
# bleu_score: 0.8067553158541243
# bleu_score: 0.8034284189446518
# Greedy: young boy in pink shirt and jeans is walking down the sidewalk
# bleu_score: 0.7127415436192576
# bleu_score: 0.7071067811865476
# bleu_score: 0.7013339980622391
# bleu_score: 0.7042381347042141
# bleu_score: 0.7059635166859475
# Greedy: two people are standing in front of water
# bleu_score: 0.7503949002834928
# bleu_score: 0.7430730989439953
# bleu_score: 0.7455377201722151
# bleu_score: 0.7467609198879429
# bleu_score: 0.7503949002834928
# Greedy: man in red coat is skiing down snowy hill
# bleu_score: 0.7644270467420534
# bleu_score: 0.7711627375699761
# bleu_score: 0.7689371364787586
# bleu_score: 0.757508443356907
# bleu_score: 0.7616822015397569
# Greedy: dog runs through the grass
# bleu_score: 0.7875110621102679
# bleu_score: 0.7971755824799469
# bleu_score: 0.7939931813032876
# bleu_score: 0.7923875245910179
# bleu_score: 0.7914194256246622
# Greedy: man in red shirt is standing on the sidewalk
# bleu_score: 0.7510499815709779
# bleu_score: 0.7300697164579737
# bleu_score: 0.7419446627365011
# bleu_score: 0.7372633901833245
# bleu_score: 0.7344112539787184
# Greedy: man in black shirt and jeans walks down the sidewalk
# bleu_score: 0.7328616209964707
# bleu_score: 0.7447819789879647
# bleu_score: 0.7447819789879647
# bleu_score: 0.7447819789879647
# bleu_score: 0.7447819789879647
# Greedy: man in white shirt and white shirt and white shirt and white shirt and white shirt and white shirt and white shirt and white shirt and white shirt and white shirt and white
# bleu_score: 0.5028819637145844
# bleu_score: 0.5028819637145844
# bleu_score: 0.5028819637145844
# bleu_score: 0.5028819637145844
# bleu_score: 0.5028819637145844
# Greedy: man in red shirt is standing on the edge of the water
# bleu_score: 0.7169073641343396
# bleu_score: 0.7169073641343396
# bleu_score: 0.7169073641343396
# bleu_score: 0.7169073641343396
# bleu_score: 0.7169073641343396
# Greedy: little girl in pink shirt is sitting on the floor
# bleu_score: 0.6883338880800094
# bleu_score: 0.6883338880800094
# bleu_score: 0.6830589102089537
# bleu_score: 0.6843891188655555
# bleu_score: 0.6851835358949973
# Greedy: dog is running through the water
# bleu_score: 0.7825422900366437
# bleu_score: 0.7657035784021965
# bleu_score: 0.7714395865600262
# bleu_score: 0.7742602536706181
# bleu_score: 0.7792611180307638
# Greedy: boy in red shirt is jumping on the playground
# bleu_score: 0.7839874343080119
# bleu_score: 0.7721947901921794
# bleu_score: 0.7801157731069053
# bleu_score: 0.7839874343080119
# bleu_score: 0.7793344844222023
# Greedy: dog runs through the grass
# bleu_score: 0.8065008590125561
# bleu_score: 0.8065008590125561
# bleu_score: 0.8065008590125561
# bleu_score: 0.8065008590125561
# bleu_score: 0.8028096826991373
# Greedy: hockey player in red uniform is playing on the ice
# bleu_score: 0.7521206186172787
# bleu_score: 0.7579289311365565
# bleu_score: 0.7598356856515925
# bleu_score: 0.7636066981663598
# bleu_score: 0.7613508191678641
# Greedy: young boy in pink shirt is jumping up the air
# bleu_score: 0.6865890479690392
# bleu_score: 0.7031452428005499
# bleu_score: 0.7135650476426908
# bleu_score: 0.711002833752044
# bleu_score: 0.7125434773103981
# Greedy: two children are sitting on bench
# bleu_score: 0.8210967436686386
# bleu_score: 0.7922410709252884
# bleu_score: 0.7818827510689514
# bleu_score: 0.7884044396805875
# bleu_score: 0.7891762511183534
# Greedy: child is swinging on swing
# bleu_score: 0.7203294535577252
# bleu_score: 0.7328616209964707
# bleu_score: 0.7524217680744609
# bleu_score: 0.7505336182671021
# bleu_score: 0.7539221180326289
# Greedy: dog runs through the grass
# bleu_score: 0.8065008590125561
# bleu_score: 0.8065008590125561
# bleu_score: 0.8065008590125561
# bleu_score: 0.8065008590125561
# bleu_score: 0.8065008590125561
# Greedy: black dog is running through the water
# bleu_score: 0.8055344092731546
# bleu_score: 0.8117552141258282
# bleu_score: 0.8137973817434668
# bleu_score: 0.8117552141258282
# bleu_score: 0.8129823608095036
# Greedy: man in red shirt is standing on the sidewalk
# bleu_score: 0.7226568811456053
# bleu_score: 0.7372633901833245
# bleu_score: 0.7465389668481563
# bleu_score: 0.7510499815709779
# bleu_score: 0.7510499815709779
# Greedy: two women in white and white shirts are playing in the street
# bleu_score: 0.7041908148225626
# bleu_score: 0.6982477449844272
# bleu_score: 0.6879916886761889
# bleu_score: 0.6952183991746782
# bleu_score: 0.6970407435059658
# Greedy: two dogs are playing in the grass
# bleu_score: 0.7922410709252884
# bleu_score: 0.8070557274927981
# bleu_score: 0.811817324781941
# bleu_score: 0.8141670377014885
# bleu_score: 0.8127596564026885
# Greedy: little girl in pink shirt is sitting on the grass
# bleu_score: 0.6883338880800094
# bleu_score: 0.6883338880800094
# bleu_score: 0.6883338880800094
# bleu_score: 0.6883338880800094
# bleu_score: 0.691441569283882
# Greedy: man in red shirt is jumping over the air
# bleu_score: 0.7400828044922853
# bleu_score: 0.7241577342575828
# bleu_score: 0.7348889200874658
# bleu_score: 0.7400828044922853
# bleu_score: 0.7369796636000282
# Greedy: dog runs through the grass
# bleu_score: 0.8065008590125561
# bleu_score: 0.8065008590125561
# bleu_score: 0.8065008590125561
# bleu_score: 0.8065008590125561
# bleu_score: 0.8065008590125561
# Greedy: two children are sitting on bench
# bleu_score: 0.8210967436686386
# bleu_score: 0.7922410709252884
# bleu_score: 0.7972714256536028
# bleu_score: 0.8034284189446518
# bleu_score: 0.8070557274927981
# Greedy: two children are playing in the grass
# bleu_score: 0.7842988494376653
# bleu_score: 0.7842988494376653
# bleu_score: 0.7889261820345875
# bleu_score: 0.7945981947797423
# bleu_score: 0.7952707287670506
# Greedy: woman in black shirt and white shirt and white shirt and white hair and woman in front of crowd
# bleu_score: 0.6195853032270514
# bleu_score: 0.6250447320395832
# bleu_score: 0.6232408323308517
# bleu_score: 0.616800579706554
# bleu_score: 0.6217863513967674
# Greedy: man in black shirt and jeans stands on the sidewalk
# bleu_score: 0.7105477917053864
# bleu_score: 0.7238348098810832
# bleu_score: 0.7238348098810832
# bleu_score: 0.7172835948406505
# bleu_score: 0.7212357201267043
# Greedy: two dogs are playing in the grass
# bleu_score: 0.7922410709252884
# bleu_score: 0.7845109654406773
# bleu_score: 0.7922410709252884
# bleu_score: 0.7997513045108656
# bleu_score: 0.7952707287670506
# Greedy: two people are walking on the water
# bleu_score: 0.7121043131712586
# bleu_score: 0.7400828044922853
# bleu_score: 0.7371283231463883
# bleu_score: 0.7356376616801006
# bleu_score: 0.7311104457090247
# Greedy: man is walking on the beach
# bleu_score: 0.816496580927726
# bleu_score: 0.816496580927726
# bleu_score: 0.8221085715198868
# bleu_score: 0.816496580927726
# bleu_score: 0.8130730397870789
# Greedy: man in white shirt and white dog on bench
# bleu_score: 0.7777264164917724
# bleu_score: 0.7777264164917724
# bleu_score: 0.7777264164917724
# bleu_score: 0.7777264164917724
# bleu_score: 0.7777264164917724
# Greedy: two dogs are running on the beach
# bleu_score: 0.8070557274927981
# bleu_score: 0.7997513045108656
# bleu_score: 0.7922410709252884
# bleu_score: 0.7960227586651802
# bleu_score: 0.7922410709252884
# Greedy: two women are sitting at table
# bleu_score: 0.7952707287670506
# bleu_score: 0.7952707287670506
# bleu_score: 0.7839874343080119
# bleu_score: 0.7825422900366437
# bleu_score: 0.788558983339814
# Greedy: two children are playing in the water
# bleu_score: 0.7842988494376653
# bleu_score: 0.7912096391448357
# bleu_score: 0.7934734952948062
# bleu_score: 0.7877769784277862
# bleu_score: 0.7842988494376653
# Greedy: boy in pink shirt and jeans is walking down sidewalk
# bleu_score: 0.7561559858236034
# bleu_score: 0.7447819789879647
# bleu_score: 0.7524217680744609
# bleu_score: 0.7476743906106103
# bleu_score: 0.7447819789879647
# Greedy: man in black jacket and hat is standing on sidewalk
# bleu_score: 0.7598356856515925
# bleu_score: 0.7364279629037999
# bleu_score: 0.7281054070048087
# bleu_score: 0.7270447990811325
# bleu_score: 0.7264061996076753
# Greedy: girl in pink shirt is jumping over playground
# bleu_score: 0.7839874343080119
# bleu_score: 0.7534229968600287
# bleu_score: 0.764022266591279
# bleu_score: 0.7629820704877448
# bleu_score: 0.7673226555727322
# Greedy: dog jumps over hurdle
# bleu_score: 0.8307018474412792
# bleu_score: 0.8201174971518101
# bleu_score: 0.8442136252749054
# bleu_score: 0.855526185871245
# bleu_score: 0.8545740127924681
# Greedy: woman in red shirt is standing on the street
# bleu_score: 0.7226568811456053
# bleu_score: 0.7226568811456053
# bleu_score: 0.7226568811456053
# bleu_score: 0.7263916663970521
# bleu_score: 0.7286051760516973
# Greedy: boy in blue shirt is playing in pool
# bleu_score: 0.7896895367562644
# bleu_score: 0.7966478260950647
# bleu_score: 0.7943486741979434
# bleu_score: 0.7896895367562644
# bleu_score: 0.7896895367562644
# Greedy: man in red shirt and backpack stands on rocky path
# bleu_score: 0.7140741917751113
# bleu_score: 0.727427152512826
# bleu_score: 0.727427152512826
# bleu_score: 0.7241577342575828
# bleu_score: 0.7300113038706791
# Greedy: two dogs are walking on the street
# bleu_score: 0.8010548969451144
# bleu_score: 0.7938047857077988
# bleu_score: 0.796243538816393
# bleu_score: 0.7974545591044423
# bleu_score: 0.7923306757529299
# Greedy: little boy in red shirt and red shirt is standing on sidewalk
# bleu_score: 0.6794435486105396
# bleu_score: 0.6794435486105396
# bleu_score: 0.6794435486105396
# bleu_score: 0.682686808057728
# bleu_score: 0.6846107918332553
# Greedy: child in pink shirt is sitting on bed
# bleu_score: 0.7979439453790055
# bleu_score: 0.7772003922365337
# bleu_score: 0.77958813278269
# bleu_score: 0.7772003922365337
# bleu_score: 0.7757571169429711
# Greedy: man in red shirt stands on the edge of rocks
# bleu_score: 0.7510499815709779
# bleu_score: 0.7442524500510544
# bleu_score: 0.7419446627365011
# bleu_score: 0.7476743906106103
# bleu_score: 0.7483531696941793
# Greedy: man climbing rock climbing
# bleu_score: 0.7875110621102679
# bleu_score: 0.7971755824799469
# bleu_score: 0.8003203203844999
# bleu_score: 0.7971755824799469
# bleu_score: 0.7990668782917915
# Greedy: man in black jacket and black hat is standing on the sidewalk
# bleu_score: 0.6921489273129074
# bleu_score: 0.6921489273129074
# bleu_score: 0.7002456130253102
# bleu_score: 0.6982477449844272
# bleu_score: 0.7018316834636856
# Greedy: man in red shirt is sitting on mountain
# bleu_score: 0.7287557921168066
# bleu_score: 0.7287557921168066
# bleu_score: 0.7342150184891979
# bleu_score: 0.7368995788758251
# bleu_score: 0.7384963370537888
# Greedy: man in black shirt and black shirt and black shirt and black shirt and black shirt and black shirt and black shirt and black shirt and black shirt and black shirt and black
# bleu_score: 0.5028819637145844
# bleu_score: 0.5028819637145844
# bleu_score: 0.5066491330574671
# bleu_score: 0.5057152136345391
# bleu_score: 0.5051523688965254
# Greedy: little girl in red shirt is walking through the grass
# bleu_score: 0.7293799946522604
# bleu_score: 0.7293799946522604
# bleu_score: 0.7252936714494974
# bleu_score: 0.7200866322006062
# bleu_score: 0.7219741624986888
# Greedy: man in red shirt is sitting on the snow
# bleu_score: 0.7287557921168066
# bleu_score: 0.7368995788758251
# bleu_score: 0.7342150184891979
# bleu_score: 0.7328616209964707
# bleu_score: 0.7384963370537888
# Greedy: boy in red shirt and jeans is walking down the street
# bleu_score: 0.7037475090852178
# bleu_score: 0.7037475090852178
# bleu_score: 0.708215971703208
# bleu_score: 0.7136852270233967
# bleu_score: 0.7117307991098211
# Greedy: two people are sitting on the sidewalk
# bleu_score: 0.7926416986492341
# bleu_score: 0.7790872728179328
# bleu_score: 0.7790872728179328
# bleu_score: 0.7790872728179328
# bleu_score: 0.773461726018889
# Greedy: black and white dog is jumping over the grass
# bleu_score: 0.816496580927726
# bleu_score: 0.816496580927726
# bleu_score: 0.816496580927726
# bleu_score: 0.8034284189446518
# bleu_score: 0.7930523787685403
# Greedy: two young girls in pink and white hair and smiling
# bleu_score: 0.7636066981663598
# bleu_score: 0.7579289311365565
# bleu_score: 0.7560076763164566
# bleu_score: 0.7550415303475492
# bleu_score: 0.7567779347543466
# Greedy: boy in red shirt is standing on the edge of the ocean
# bleu_score: 0.6898050097171565
# bleu_score: 0.6898050097171565
# bleu_score: 0.6800180619993327
# bleu_score: 0.678764567155257
# bleu_score: 0.678009124062636
# Greedy: young boy in pink shirt is sitting on the beach
# bleu_score: 0.7387670965262431
# bleu_score: 0.7516200388933441
# bleu_score: 0.7474091167031134
# bleu_score: 0.7484685227873459
# bleu_score: 0.7491020134286688
# Greedy: dog is jumping over small dog
# bleu_score: 0.8020396005825877
# bleu_score: 0.8102667241708824
# bleu_score: 0.8075522246377866
# bleu_score: 0.8061846461076281
# bleu_score: 0.8053607465683842
# Greedy: the man is standing on the street
# bleu_score: 0.7226568811456053
# bleu_score: 0.7419446627365011
# bleu_score: 0.7419446627365011
# bleu_score: 0.7465389668481563
# bleu_score: 0.7528318445831542
# Greedy: girl in pink dress is sitting on the bed
# bleu_score: 0.7400828044922853
# bleu_score: 0.7550415303475492
# bleu_score: 0.7550415303475492
# bleu_score: 0.7550415303475492
# bleu_score: 0.7550415303475492
# Greedy: young boy in pink shirt is standing in front of the grass
# bleu_score: 0.6910621773335011
# bleu_score: 0.697613262053043
# bleu_score: 0.6997564924064748
# bleu_score: 0.7071067811865476
# bleu_score: 0.7114092373668142
# Greedy: man wearing sunglasses and sunglasses is standing on the camera
# bleu_score: 0.7098962112020106
# bleu_score: 0.704283943279908
# bleu_score: 0.6985342056580097
# bleu_score: 0.6985342056580097
# bleu_score: 0.6961940246798876
# Greedy: man in white shirt is standing on the street
# bleu_score: 0.7226568811456053
# bleu_score: 0.715008642007595
# bleu_score: 0.7175852914772133
# bleu_score: 0.7226568811456053
# bleu_score: 0.7256493131878406
# Greedy: two dogs are playing in the snow
# bleu_score: 0.8132882808488929
# bleu_score: 0.8132882808488929
# bleu_score: 0.8180866499595517
# bleu_score: 0.8204545087278228
# bleu_score: 0.81903625881272
# Greedy: woman in pink shirt is standing on the edge of the water
# bleu_score: 0.6657346545088059
# bleu_score: 0.6803749333171202
# bleu_score: 0.6803749333171202
# bleu_score: 0.6838911999336902
# bleu_score: 0.6775221454063249
# Greedy: the man is sitting on the sidewalk
# bleu_score: 0.7707713836060629
# bleu_score: 0.7541859578343534
# bleu_score: 0.7598356856515925
# bleu_score: 0.7626139246288385
# bleu_score: 0.764266402192522
# Greedy: boy in red shirt is jumping over the air
# bleu_score: 0.7400828044922853
# bleu_score: 0.7400828044922853
# bleu_score: 0.7348889200874658
# bleu_score: 0.7439076491940827
# bleu_score: 0.7431473951103933
# Greedy: two dogs are playing in the grass
# bleu_score: 0.7419446627365011
# bleu_score: 0.7683267876953447
# bleu_score: 0.7710955777402456
# bleu_score: 0.7641166194509462
# bleu_score: 0.7699916442331549
# Greedy: man is climbing rock rock
# bleu_score: 0.8323582900575635
# bleu_score: 0.8144476398584994
# bleu_score: 0.8205487975886251
# bleu_score: 0.81903625881272
# bleu_score: 0.8217528342788757
# Greedy: young girl in pink shirt is playing with her hair
# bleu_score: 0.7034711503007025
# bleu_score: 0.7244933810379663
# bleu_score: 0.7222468628919761
# bleu_score: 0.7278244729081154
# bleu_score: 0.7311104457090247
# Greedy: child in pink shirt is sitting on the inflatable
# bleu_score: 0.7598356856515925
# bleu_score: 0.7538286083107645
# bleu_score: 0.7476743906106103
# bleu_score: 0.7538286083107645
# bleu_score: 0.7526098030180586
# Greedy: two girls are playing on the street
# bleu_score: 0.7806724026248424
# bleu_score: 0.7730551756939454
# bleu_score: 0.7806724026248424
# bleu_score: 0.7806724026248424
# bleu_score: 0.7806724026248424
# Greedy: man is climbing rock rock
# bleu_score: 0.8144476398584994
# bleu_score: 0.8050304775850328
# bleu_score: 0.8082062018706494
# bleu_score: 0.8050304775850328
# bleu_score: 0.8069404091034159
# Greedy: two women in front of the street
# bleu_score: 0.7657035784021965
# bleu_score: 0.7568500260087727
# bleu_score: 0.7476743906106103
# bleu_score: 0.7381479309342973
# bleu_score: 0.7400828044922853
# Greedy: man in red shirt is jumping over the air
# bleu_score: 0.7400828044922853
# bleu_score: 0.7241577342575828
# bleu_score: 0.7295825158420239
# bleu_score: 0.7322501380936575
# bleu_score: 0.7369796636000282
# Greedy: little boy in pink shirt is standing on the sidewalk
# bleu_score: 0.7447819789879647
# bleu_score: 0.7505336182671021
# bleu_score: 0.7447819789879647
# bleu_score: 0.7418554706133851
# bleu_score: 0.7400828044922853
# Greedy: boy in red shirt is jumping on the grass
# bleu_score: 0.7825422900366437
# bleu_score: 0.7825422900366437
# bleu_score: 0.7910959350908626
# bleu_score: 0.7889835105370939
# bleu_score: 0.7877078660896708
# Greedy: dog is running through the water
# bleu_score: 0.7825422900366437
# bleu_score: 0.7905694150420948
# bleu_score: 0.7879209040715778
# bleu_score: 0.7905694150420948
# bleu_score: 0.7889835105370939
# Greedy: two dogs are playing in the grass
# bleu_score: 0.8070557274927981
# bleu_score: 0.7997513045108656
# bleu_score: 0.7972714256536028
# bleu_score: 0.7960227586651802
# bleu_score: 0.7952707287670506
# Greedy: dog is playing with ball in the grass
# bleu_score: 0.7979439453790055
# bleu_score: 0.80451193916621
# bleu_score: 0.8066659395368106
# bleu_score: 0.80451193916621
# bleu_score: 0.8058064114761131
# Greedy: man is walking on the beach
# bleu_score: 0.8633400213704505
# bleu_score: 0.8485766316739435
# bleu_score: 0.838288953121957
# bleu_score: 0.836976045486186
# bleu_score: 0.8361853256187297
# Greedy: man in white shirt is jumping into the air
# bleu_score: 0.7598356856515925
# bleu_score: 0.7529586373193689
# bleu_score: 0.7506238537503395
# bleu_score: 0.7422756664604733
# bleu_score: 0.7400828044922853
# Greedy: two children are sitting on the edge of the water
# bleu_score: 0.7438301789874407
# bleu_score: 0.7375525698389189
# bleu_score: 0.7354239688001339
# bleu_score: 0.7244933810379663
# bleu_score: 0.7204344348989306
# Greedy: man climbing rock climbing
# bleu_score: 0.7875110621102679
# bleu_score: 0.7971755824799469
# bleu_score: 0.8003203203844999
# bleu_score: 0.7971755824799469
# bleu_score: 0.7990668782917915
# Greedy: man in red jacket is skiing down snowy hill
# bleu_score: 0.7685209321928833
# bleu_score: 0.7620349436284882
# bleu_score: 0.764215323401781
# bleu_score: 0.7652985512420392
# bleu_score: 0.7633454126881933
# Greedy: man wearing sunglasses and sunglasses is smiling on the camera
# bleu_score: 0.6893409630302637
# bleu_score: 0.7013339980622391
# bleu_score: 0.7051982434564569
# bleu_score: 0.7071067811865476
# bleu_score: 0.70824452707176
# Greedy: woman in red shirt is standing in front of crowd
# bleu_score: 0.7348889200874658
# bleu_score: 0.7413643379571916
# bleu_score: 0.7392247360299167
# bleu_score: 0.7381479309342973
# bleu_score: 0.7348889200874658
# Greedy: woman in black shirt and black hair and black hair and black hair
# bleu_score: 0.6930977286178778
# bleu_score: 0.6872482796913578
# bleu_score: 0.6892146754069327
# bleu_score: 0.690191594478631
# bleu_score: 0.6860602920528499
# Greedy: girl in pink shirt is jumping on trampoline
# bleu_score: 0.7685209321928833
# bleu_score: 0.7620349436284882
# bleu_score: 0.7685209321928833
# bleu_score: 0.7717032815520658
# bleu_score: 0.7685209321928833
# Greedy: two people are playing in the water
# bleu_score: 0.7487402156832422
# bleu_score: 0.7571073267517036
# bleu_score: 0.7652058832556895
# bleu_score: 0.7529586373193689
# bleu_score: 0.7521206186172787
# Greedy: woman in pink dress is walking on the street
# bleu_score: 0.7372633901833245
# bleu_score: 0.7300697164579737
# bleu_score: 0.7276238873928836
# bleu_score: 0.7300697164579737
# bleu_score: 0.7372633901833245
# Greedy: man in red jacket is standing on snowy hill
# bleu_score: 0.6944370541455951
# bleu_score: 0.7415129228605242
# bleu_score: 0.7415129228605242
# bleu_score: 0.7342777853218713
# bleu_score: 0.7415129228605242
# Greedy: dog runs through the grass
# bleu_score: 0.8065008590125561
# bleu_score: 0.7971755824799469
# bleu_score: 0.8003203203844999
# bleu_score: 0.7971755824799469
# bleu_score: 0.7990668782917915
# Greedy: man in white shirt and white shirt is playing in the grass
# bleu_score: 0.7009305846091448
# bleu_score: 0.7071067811865476
# bleu_score: 0.6924328859069189
# bleu_score: 0.6945866689456455
# bleu_score: 0.6958693829387109
# Greedy: man in blue shirt is playing with his arms
# bleu_score: 0.7458878201607712
# bleu_score: 0.7458878201607712
# bleu_score: 0.7410598136218668
# bleu_score: 0.7422756664604733
# bleu_score: 0.7458878201607712
# Greedy: young boy wearing red shirt and white shirt is jumping up the air
# bleu_score: 0.6812455364200614
# bleu_score: 0.6812455364200614
# bleu_score: 0.6812455364200614
# bleu_score: 0.6872482796913578
# bleu_score: 0.6884301383638523
# Greedy: two boys play soccer ball
# bleu_score: 0.8323582900575635
# bleu_score: 0.8235490260528069
# bleu_score: 0.8205487975886251
# bleu_score: 0.8235490260528069
# bleu_score: 0.8217528342788757
# Greedy: the man is standing on the water
# bleu_score: 0.7476743906106103
# bleu_score: 0.7742602536706181
# bleu_score: 0.7770504259213554
# bleu_score: 0.7784343146194425
# bleu_score: 0.7759379671981613
# Greedy: man wearing helmet rides bike on bike
# bleu_score: 0.8109228996775397
# bleu_score: 0.8109228996775397
# bleu_score: 0.7934734952948062
# bleu_score: 0.7979439453790055
# bleu_score: 0.7952707287670506
# Greedy: group of people are standing in front of building
# bleu_score: 0.7311104457090247
# bleu_score: 0.7244933810379663
# bleu_score: 0.7222468628919761
# bleu_score: 0.7211156975370338
# bleu_score: 0.7149134576995679
# Greedy: man is riding bike on dirt path
# bleu_score: 0.8047211478535489
# bleu_score: 0.7968692709603956
# bleu_score: 0.7995123230694224
# bleu_score: 0.7968692709603956
# bleu_score: 0.7920444118382948
# Greedy: man in red shirt is riding bike on bike
# bleu_score: 0.7447819789879647
# bleu_score: 0.7524217680744609
# bleu_score: 0.754917396922829
# bleu_score: 0.7598356856515925
# bleu_score: 0.7568962275183742
# Greedy: group of people sit on the beach
# bleu_score: 0.7825422900366437
# bleu_score: 0.798359216893685
# bleu_score: 0.798359216893685
# bleu_score: 0.8059274488676564
# bleu_score: 0.8103679885263144
# Greedy: boy jumps into pool pool
# bleu_score: 0.8408964152537145
# bleu_score: 0.8408964152537145
# bleu_score: 0.8349950232057651
# bleu_score: 0.8274377299117183
# bleu_score: 0.8301821713362141
# Greedy: young girl in pink bathing suit is sitting on the beach
# bleu_score: 0.745626883328766
# bleu_score: 0.7165579655913892
# bleu_score: 0.7186082239261684
# bleu_score: 0.7226568811456053
# bleu_score: 0.7177902280371525
# Greedy: group of people are sitting on the street
# bleu_score: 0.7355282324972029
# bleu_score: 0.7503949002834928
# bleu_score: 0.7503949002834928
# bleu_score: 0.7503949002834928
# bleu_score: 0.753264531608472
# Greedy: man in white shirt is standing on the grass
# bleu_score: 0.6944370541455951
# bleu_score: 0.7111824933579799
# bleu_score: 0.7111824933579799
# bleu_score: 0.7151893138203724
# bleu_score: 0.7206881537038508
# Greedy: boy in red shirt is jumping on the sidewalk
# bleu_score: 0.7685209321928833
# bleu_score: 0.7748467408379779
# bleu_score: 0.764215323401781
# bleu_score: 0.7685209321928833
# bleu_score: 0.771069958670232
# Greedy: two women are standing outside
# bleu_score: 0.8113449257895087
# bleu_score: 0.7952707287670506
# bleu_score: 0.7896895367562644
# bleu_score: 0.7910959350908626
# bleu_score: 0.788558983339814
# Greedy: man in red shirt is jumping into the ocean
# bleu_score: 0.7311104457090247
# bleu_score: 0.7386099955930606
# bleu_score: 0.7458878201607712
# bleu_score: 0.7494482450470272
# bleu_score: 0.7515603794065152
# Greedy: man in black shirt and black shirt and black pants is standing on the sidewalk
# bleu_score: 0.6729864884660303
# bleu_score: 0.6832640638317855
# bleu_score: 0.6832640638317855
# bleu_score: 0.6729864884660303
# bleu_score: 0.668740304976422
# Greedy: group of people are standing in front of the street
# bleu_score: 0.7105477917053864
# bleu_score: 0.7238348098810832
# bleu_score: 0.7238348098810832
# bleu_score: 0.7270447990811325
# bleu_score: 0.728950568505202
# Greedy: man in red shirt is riding bike
# bleu_score: 0.7887781797427305
# bleu_score: 0.7804301458376864
# bleu_score: 0.7775870015150342
# bleu_score: 0.7804301458376864
# bleu_score: 0.7787279979828097
# Greedy: person is riding through the snow
# bleu_score: 0.7226568811456053
# bleu_score: 0.7510499815709779
# bleu_score: 0.7540127609098941
# bleu_score: 0.7598356856515925
# bleu_score: 0.7598356856515925
# Greedy: brown dog is running through the grass
# bleu_score: 0.749634235443537
# bleu_score: 0.7573237977750366
# bleu_score: 0.7647860170437231
# bleu_score: 0.7610823439621528
# bleu_score: 0.761827408333416
# Greedy: two dogs are running through the grass
# bleu_score: 0.7647860170437231
# bleu_score: 0.749634235443537
# bleu_score: 0.744373319312051
# bleu_score: 0.7456990116859172
# bleu_score: 0.7464910457408166
# Greedy: man in red shirt and helmet is riding bike
# bleu_score: 0.7458878201607712
# bleu_score: 0.7386099955930606
# bleu_score: 0.7311104457090247
# bleu_score: 0.7348889200874658
# bleu_score: 0.7341378829081064
# Greedy: man in white shirt is playing with his hand
# bleu_score: 0.726822222964718
# bleu_score: 0.7342777853218713
# bleu_score: 0.7318178586755459
# bleu_score: 0.7342777853218713
# bleu_score: 0.7386443471498166
# Greedy: boy in red shirt is jumping over the air
# bleu_score: 0.7400828044922853
# bleu_score: 0.7691605673134586
# bleu_score: 0.7598356856515925
# bleu_score: 0.7586456496026764
# bleu_score: 0.7663987253535437
# Greedy: dog runs through the beach
# bleu_score: 0.8242367502646054
# bleu_score: 0.8326915667169545
# bleu_score: 0.8299019410274894
# bleu_score: 0.8242367502646054
# bleu_score: 0.8276498118796414
# Greedy: girl in pink dress is standing in front of her head
# bleu_score: 0.7364279629037999
# bleu_score: 0.7238348098810832
# bleu_score: 0.7238348098810832
# bleu_score: 0.7205815373945794
# bleu_score: 0.7186082239261684
# Greedy: man in red shirt is standing on the street
# bleu_score: 0.7311104457090247
# bleu_score: 0.7233727382700316
# bleu_score: 0.7098962112020106
# bleu_score: 0.7071067811865476
# bleu_score: 0.7121043131712586
# Greedy: little boy is playing on the playground
# bleu_score: 0.7875110621102679
# bleu_score: 0.7808648049567934
# bleu_score: 0.7830990618509682
# bleu_score: 0.7774770252727657
# bleu_score: 0.7767941286760337
# Greedy: boy in red shirt is swinging on the grass
# bleu_score: 0.719701167348513
# bleu_score: 0.7277437694115145
# bleu_score: 0.725092564076376
# bleu_score: 0.719701167348513
# bleu_score: 0.7229504651513755
# Greedy: two dogs are playing on the grass
# bleu_score: 0.7922410709252884
# bleu_score: 0.7997513045108656
# bleu_score: 0.7871130275822675
# bleu_score: 0.7960227586651802
# bleu_score: 0.7922410709252884
# Greedy: two dogs are playing in the grass
# bleu_score: 0.8210967436686386
# bleu_score: 0.8070557274927981
# bleu_score: 0.811817324781941
# bleu_score: 0.8070557274927981
# bleu_score: 0.8041578145382057
# Greedy: dog runs through the grass
# bleu_score: 0.8065008590125561
# bleu_score: 0.8065008590125561
# bleu_score: 0.8065008590125561
# bleu_score: 0.8065008590125561
# bleu_score: 0.8028096826991373
# Greedy: man in white shirt is playing guitar
# bleu_score: 0.7896895367562644
# bleu_score: 0.7966478260950647
# bleu_score: 0.7989272423094768
# bleu_score: 0.7931915718197564
# bleu_score: 0.792494872358107
# Greedy: two boys are playing soccer
# bleu_score: 0.8485766316739435
# bleu_score: 0.8485766316739435
# bleu_score: 0.8485766316739435
# bleu_score: 0.8485766316739435
# bleu_score: 0.8485766316739435
# Greedy: dog is jumping over the grass
# bleu_score: 0.7847813466510527
# bleu_score: 0.8182506116172393
# bleu_score: 0.8182506116172393
# bleu_score: 0.8102667241708824
# bleu_score: 0.8118824185823103
# Greedy: two young boys sit on bench
# bleu_score: 0.816496580927726
# bleu_score: 0.7896895367562644
# bleu_score: 0.7928047433351474
# bleu_score: 0.7989272423094768
# bleu_score: 0.7915630719552208
# Greedy: dog is standing on the edge of the mountains
# bleu_score: 0.6904573083274563
# bleu_score: 0.6904573083274563
# bleu_score: 0.6846301434209174
# bleu_score: 0.686100893342689
# bleu_score: 0.6834466815318615
# Greedy: motorcycle racer in the air
# bleu_score: 0.7598356856515925
# bleu_score: 0.7801157731069053
# bleu_score: 0.7928047433351474
# bleu_score: 0.7989272423094768
# bleu_score: 0.7952707287670506
# Greedy: black dog is running through the water
# bleu_score: 0.7926416986492341
# bleu_score: 0.799166048865006
# bleu_score: 0.7790872728179328
# bleu_score: 0.7893181801820351
# bleu_score: 0.7926416986492341
# Greedy: boy in pink swimsuit is swimming in pool
# bleu_score: 0.7400828044922853
# bleu_score: 0.7322501380936575
# bleu_score: 0.7186082239261684
# bleu_score: 0.7282376575609851
# bleu_score: 0.727427152512826
# Greedy: two children are playing together in the grass
# bleu_score: 0.7556720457448196
# bleu_score: 0.7556720457448196
# bleu_score: 0.7556720457448196
# bleu_score: 0.7588011894672505
# bleu_score: 0.7581784550983027
# Greedy: man in helmet is riding bike
# bleu_score: 0.7916963878457504
# bleu_score: 0.7916963878457504
# bleu_score: 0.7976271123027049
# bleu_score: 0.8091067115702212
# bleu_score: 0.8091067115702212
# Greedy: two young boys are sitting on the grass
# bleu_score: 0.6930977286178778
# bleu_score: 0.7025297977970931
# bleu_score: 0.7115965735877551
# bleu_score: 0.7203294535577252
# bleu_score: 0.7186082239261684
# Greedy: dog is running through the water
# bleu_score: 0.798359216893685
# bleu_score: 0.7905694150420948
# bleu_score: 0.7879209040715778
# bleu_score: 0.7905694150420948
# bleu_score: 0.7921458324706105
# Greedy: group of people are standing on the ground
# bleu_score: 0.7730551756939454
# bleu_score: 0.7529586373193689
# bleu_score: 0.7458878201607712
# bleu_score: 0.7458878201607712
# bleu_score: 0.7515603794065152
# Greedy: white dog runs through the grass
# bleu_score: 0.798359216893685
# bleu_score: 0.798359216893685
# bleu_score: 0.798359216893685
# bleu_score: 0.798359216893685
# bleu_score: 0.798359216893685
# Greedy: man in red shirt is riding bike
# bleu_score: 0.7887781797427305
# bleu_score: 0.7968692709603956
# bleu_score: 0.7941996546483427
# bleu_score: 0.7968692709603956
# bleu_score: 0.7984582504770441
# Greedy: dog is jumping over the water
# bleu_score: 0.8020396005825877
# bleu_score: 0.8335516383402117
# bleu_score: 0.8433024381672091
# bleu_score: 0.8480536257973762
# bleu_score: 0.8508664459247355
# Greedy: surfer is surfing through the ocean
# bleu_score: 0.7652058832556895
# bleu_score: 0.7652058832556895
# bleu_score: 0.7652058832556895
# bleu_score: 0.7571073267517036
# bleu_score: 0.7521206186172787
# Greedy: young girl wearing pink shirt and pink shirt is smiling in the grass
# bleu_score: 0.6964705665515708
# bleu_score: 0.6909644385321979
# bleu_score: 0.6964705665515708
# bleu_score: 0.6991753575083306
# bleu_score: 0.702910116453418
# Greedy: man in red hat is standing on the sidewalk
# bleu_score: 0.7153784423080968
# bleu_score: 0.7153784423080968
# bleu_score: 0.7259795291154771
# bleu_score: 0.7311104457090247
# bleu_score: 0.7311104457090247
# Greedy: dog is running through the water
# bleu_score: 0.798359216893685
# bleu_score: 0.7825422900366437
# bleu_score: 0.7879209040715778
# bleu_score: 0.7865865709114471
# bleu_score: 0.7857827000904407
# Greedy: man is jumping into the water
# bleu_score: 0.8020396005825877
# bleu_score: 0.8020396005825877
# bleu_score: 0.7964109047822965
# bleu_score: 0.793551214429417
# bleu_score: 0.7952707287670506
# Greedy: boy is walking on the sidewalk
# bleu_score: 0.8113449257895087
# bleu_score: 0.8034284189446518
# bleu_score: 0.7952707287670506
# bleu_score: 0.7952707287670506
# bleu_score: 0.7952707287670506
# Greedy: man is riding bike bike down dirt bike
# bleu_score: 0.7647860170437231
# bleu_score: 0.7647860170437231
# bleu_score: 0.7547866639718852
# bleu_score: 0.749634235443537
# bleu_score: 0.7558045849143014
# Greedy: young boy with his hair hair and baby
# bleu_score: 0.7699019277569183
# bleu_score: 0.7699019277569183
# bleu_score: 0.7649184819342956
# bleu_score: 0.7623897911954858
# bleu_score: 0.7639100176693358
# Greedy: man in red shirt is jumping over the water
# bleu_score: 0.7311104457090247
# bleu_score: 0.7386099955930606
# bleu_score: 0.736135555475544
# bleu_score: 0.7311104457090247
# bleu_score: 0.7371283231463883
# Greedy: man in red shirt is riding bike
# bleu_score: 0.7718052844994459
# bleu_score: 0.7718052844994459
# bleu_score: 0.7775870015150342
# bleu_score: 0.7846374688658063
# bleu_score: 0.7887781797427305
# Greedy: dog is walking on the beach
# bleu_score: 0.8329997998131278
# bleu_score: 0.8329997998131278
# bleu_score: 0.838288953121957
# bleu_score: 0.8408964152537145
# bleu_score: 0.8455296286850276
# Greedy: black and white dog is running through the grass
# bleu_score: 0.7598356856515925
# bleu_score: 0.7476743906106103
# bleu_score: 0.7434855737622396
# bleu_score: 0.7507704170402972
# bleu_score: 0.7526098030180586
# Greedy: two dogs are playing in the grass
# bleu_score: 0.8070557274927981
# bleu_score: 0.8141670377014885
# bleu_score: 0.811817324781941
# bleu_score: 0.8141670377014885
# bleu_score: 0.8127596564026885
# Greedy: dog runs through the water
# bleu_score: 0.8065008590125561
# bleu_score: 0.8155134405766568
# bleu_score: 0.8125424861344327
# bleu_score: 0.8155134405766568
# bleu_score: 0.8137347747205208
# Greedy: woman in red shirt and red hat is wearing red hat and red hat
# bleu_score: 0.6197666010674405
# bleu_score: 0.6363082311973168
# bleu_score: 0.6466581003833891
# bleu_score: 0.6479174210512485
# bleu_score: 0.648669502898792
# Greedy: woman in red hat walks down street
# bleu_score: 0.8010548969451144
# bleu_score: 0.7938047857077988
# bleu_score: 0.796243538816393
# bleu_score: 0.7974545591044423
# bleu_score: 0.798178531306265
# Greedy: child in red shirt is jumping over the water
# bleu_score: 0.7765453555044466
# bleu_score: 0.7825422900366437
# bleu_score: 0.7765453555044466
# bleu_score: 0.7765453555044466
# bleu_score: 0.7691605673134586
# Greedy: boy in pink shirt is jumping into the water
# bleu_score: 0.7810213065790322
# bleu_score: 0.7810213065790322
# bleu_score: 0.7810213065790322
# bleu_score: 0.7810213065790322
# bleu_score: 0.7785690901084049
# Greedy: man in helmet is riding bike
# bleu_score: 0.8408964152537145
# bleu_score: 0.8332857102035374
# bleu_score: 0.8254605646966103
# bleu_score: 0.8254605646966103
# bleu_score: 0.8222672338010394
# Greedy: dog runs through the water
# bleu_score: 0.8242367502646054
# bleu_score: 0.8155134405766568
# bleu_score: 0.8065008590125561
# bleu_score: 0.8065008590125561
# bleu_score: 0.8028096826991373
# Greedy: boy in red shirt and jeans is playing in the grass
# bleu_score: 0.7400828044922853
# bleu_score: 0.7400828044922853
# bleu_score: 0.7400828044922853
# bleu_score: 0.7400828044922853
# bleu_score: 0.7425375075264609
# Greedy: young boy in pink shirt is jumping into the air
# bleu_score: 0.7387670965262431
# bleu_score: 0.7181299486370114
# bleu_score: 0.7157241193562004
# bleu_score: 0.7145120504530563
# bleu_score: 0.7195619197522996
# Greedy: man in red shirt is standing on the sidewalk
# bleu_score: 0.6904573083274563
# bleu_score: 0.7071067811865476
# bleu_score: 0.7175852914772133
# bleu_score: 0.7263916663970521
# bleu_score: 0.7286051760516973
# Greedy: two girls are sitting on the street
# bleu_score: 0.7487402156832422
# bleu_score: 0.7571073267517036
# bleu_score: 0.7487402156832422
# bleu_score: 0.7487402156832422
# bleu_score: 0.7453133970777198
# Greedy: man in red shirt is standing on the edge of the ocean
# bleu_score: 0.7037475090852178
# bleu_score: 0.7037475090852178
# bleu_score: 0.7037475090852178
# bleu_score: 0.7037475090852178
# bleu_score: 0.7037475090852178
# Greedy: man in black shirt and black shirt is sitting on the sidewalk
# bleu_score: 0.6659825542555479
# bleu_score: 0.6921489273129074
# bleu_score: 0.6962325789663253
# bleu_score: 0.6982477449844272
# bleu_score: 0.7018316834636856
# Greedy: man in red shirt is jumping on the street
# bleu_score: 0.719701167348513
# bleu_score: 0.7277437694115145
# bleu_score: 0.7355282324972029
# bleu_score: 0.7316670585565402
# bleu_score: 0.7385739632005542
# Greedy: group of people are standing in front of building
# bleu_score: 0.7311104457090247
# bleu_score: 0.7311104457090247
# bleu_score: 0.7222468628919761
# bleu_score: 0.7244933810379663
# bleu_score: 0.7092615246389123
# Greedy: man in red shirt is standing on the street
# bleu_score: 0.7311104457090247
# bleu_score: 0.7311104457090247
# bleu_score: 0.7259795291154771
# bleu_score: 0.7233727382700316
# bleu_score: 0.7186082239261684
# Greedy: two young boys are sitting on the grass
# bleu_score: 0.7447819789879647
# bleu_score: 0.7524217680744609
# bleu_score: 0.7499010567121387
# bleu_score: 0.7486311096379878
# bleu_score: 0.7539221180326289
# Greedy: man in blue shirt is riding bike on dirt bike
# bleu_score: 0.7468422531048421
# bleu_score: 0.7331329005620809
# bleu_score: 0.7186082239261684
# bleu_score: 0.7295825158420239
# bleu_score: 0.7331329005620809
# Greedy: man in black shirt is skateboarding down railing
# bleu_score: 0.7714395865600262
# bleu_score: 0.7476743906106103
# bleu_score: 0.7259795291154771
# bleu_score: 0.7315859649494699
# bleu_score: 0.7295825158420239
# Greedy: young boy is walking on beach
# bleu_score: 0.8182506116172393
# bleu_score: 0.8260074086962012
# bleu_score: 0.8234461145823753
# bleu_score: 0.8260074086962012
# bleu_score: 0.8213797341444489
# Greedy: man wearing hat and hat is standing in front of crowd
# bleu_score: 0.6898050097171565
# bleu_score: 0.7104188473589647
# bleu_score: 0.7037475090852178
# bleu_score: 0.7037475090852178
# bleu_score: 0.7064387532503688
# Greedy: man in white shirt is sitting on the sidewalk
# bleu_score: 0.6865890479690392
# bleu_score: 0.7031452428005499
# bleu_score: 0.7135650476426908
# bleu_score: 0.711002833752044
# bleu_score: 0.7155951251868898
# Greedy: man in red shirt is jumping on skateboard
# bleu_score: 0.8024468307724723
# bleu_score: 0.7964802694918147
# bleu_score: 0.7984840092721571
# bleu_score: 0.7903765226488096
# bleu_score: 0.7828602028749319
# Greedy: man in red shirt is standing on rocky rocks
# bleu_score: 0.7685209321928833
# bleu_score: 0.7620349436284882
# bleu_score: 0.7508419632761159
# bleu_score: 0.7450524645887482
# bleu_score: 0.7443485880689545
# Greedy: woman in black and white hair and woman in the background
# bleu_score: 0.7278825061958952
# bleu_score: 0.7162326270441588
# bleu_score: 0.7162326270441588
# bleu_score: 0.7101879294518632
# bleu_score: 0.7138331540389101
# Greedy: woman wearing red hat and hat is standing in front of the street
# bleu_score: 0.6713374035706625
# bleu_score: 0.6777015027073836
# bleu_score: 0.6797835595004185
# bleu_score: 0.6808174538328751
# bleu_score: 0.681435536588141
# Greedy: two dogs are playing in the snow
# bleu_score: 0.798359216893685
# bleu_score: 0.798359216893685
# bleu_score: 0.8034284189446518
# bleu_score: 0.8059274488676564
# bleu_score: 0.8044308269063533
# Greedy: woman in red shirt is standing on the street
# bleu_score: 0.6904573083274563
# bleu_score: 0.6989307622784944
# bleu_score: 0.7124038313502759
# bleu_score: 0.715008642007595
# bleu_score: 0.7196268065305191
# Greedy: woman in pink shirt is standing on the sidewalk
# bleu_score: 0.7387670965262431
# bleu_score: 0.7452766866529279
# bleu_score: 0.7474091167031134
# bleu_score: 0.7387670965262431
# bleu_score: 0.7387670965262431
# Greedy: two children are standing on the sidewalk
# bleu_score: 0.7644270467420534
# bleu_score: 0.7355282324972029
# bleu_score: 0.7405837068463458
# bleu_score: 0.7355282324972029
# bleu_score: 0.7385739632005542
# Greedy: young boy in pink shirt is sitting on the edge of the water
# bleu_score: 0.721634009677548
# bleu_score: 0.710084138739636
# bleu_score: 0.7061059198231312
# bleu_score: 0.710084138739636
# bleu_score: 0.7124393423456432
# Greedy: two young girls sitting on bench
# bleu_score: 0.798359216893685
# bleu_score: 0.7905694150420948
# bleu_score: 0.798359216893685
# bleu_score: 0.8059274488676564
# bleu_score: 0.8074157792118413
# Greedy: boy in blue shirt is jumping into the air
# bleu_score: 0.7777264164917724
# bleu_score: 0.7711627375699761
# bleu_score: 0.7820115726815385
# bleu_score: 0.7809468846136748
# bleu_score: 0.780305975674519
# Greedy: boy is playing with his mouth
# bleu_score: 0.8020396005825877
# bleu_score: 0.8102667241708824
# bleu_score: 0.8234461145823753
# bleu_score: 0.8182506116172393
# bleu_score: 0.8150851727457197
# Greedy: person is jumping over snowy hill
# bleu_score: 0.7419446627365011
# bleu_score: 0.7419446627365011
# bleu_score: 0.7419446627365011
# bleu_score: 0.7554811471453416
# bleu_score: 0.7666510377252865
# ...
# bleu_score: 0.7505830556495964
# Greedy: dog is running through the water
# bleu_score: 0.798359216893685
# bleu_score: 0.798359216893685
# bleu_score: 0.798359216893685
# bleu_score: 0.7905694150420948
# bleu_score: 0.7921458324706105
# Greedy: boy in red shirt is standing on the street
# bleu_score: 0.6985342056580097
# bleu_score: 0.7233727382700316
# bleu_score: 0.7311104457090247
# bleu_score: 0.7272724630511277
# bleu_score: 0.7280449255982145
# Greedy: boy with his mouth
# bleu_score: 0.7598356856515925
# bleu_score: 0.8034284189446518
# bleu_score: 0.8078551893223442
# bleu_score: 0.816496580927726
# bleu_score: 0.8265168183793802
# Greedy: man in helmet is riding bike
# bleu_score: 0.8254605646966103
# bleu_score: 0.8254605646966103
# bleu_score: 0.8201174971518101
# bleu_score: 0.8132882808488929
# bleu_score: 0.81903625881272
# Greedy: two dogs are playing in the water
# bleu_score: 0.7922410709252884
# bleu_score: 0.7845109654406773
# bleu_score: 0.7818827510689514
# bleu_score: 0.7805586434374694
# bleu_score: 0.7829372143561522
# Greedy: dog is running through the grass
# bleu_score: 0.7825422900366437
# bleu_score: 0.7825422900366437
# bleu_score: 0.7825422900366437
# bleu_score: 0.7784343146194425
# bleu_score: 0.7792611180307638
# Greedy: young boy in red shirt is running on the grass
# bleu_score: 0.7427498127683173
# bleu_score: 0.7360274036243225
# bleu_score: 0.738288651163916
# bleu_score: 0.732595946991973
# bleu_score: 0.7234411002930288
# Greedy: man in red shirt and white hat is sitting on bench
# bleu_score: 0.727427152512826
# bleu_score: 0.727427152512826
# bleu_score: 0.727427152512826
# bleu_score: 0.727427152512826
# bleu_score: 0.727427152512826
# Greedy: group of people are standing in front of crowd
# bleu_score: 0.7556720457448196
# bleu_score: 0.7618920933187863
# bleu_score: 0.7556720457448196
# bleu_score: 0.7556720457448196
# bleu_score: 0.7531404455270682
# Greedy: dog is jumping over the grass
# bleu_score: 0.8020396005825877
# bleu_score: 0.793551214429417
# bleu_score: 0.7964109047822965
# bleu_score: 0.793551214429417
# bleu_score: 0.7918204490244928
# Greedy: child in blue shirt is swinging on swing
# bleu_score: 0.7400828044922853
# bleu_score: 0.7621991222319221
# bleu_score: 0.7501542733805745
# bleu_score: 0.7476743906106103
# bleu_score: 0.7431473951103933
# Greedy: young boy in red shirt is walking on beach
# bleu_score: 0.7598356856515925
# bleu_score: 0.7794183063631209
# bleu_score: 0.7815051210379896
# bleu_score: 0.7762563007901254
# bleu_score: 0.7781581271306612
# Greedy: two people are sitting on the snow
# bleu_score: 0.7863503941633413
# bleu_score: 0.7786777655685517
# bleu_score: 0.7760690931795545
# bleu_score: 0.7747548308973496
# bleu_score: 0.7771157160472033
# Greedy: man in white shirt and white shorts is walking on beach
# bleu_score: 0.7102992180127422
# bleu_score: 0.7102992180127422
# bleu_score: 0.7060329636905439
# bleu_score: 0.7071067811865476
# bleu_score: 0.7128225231744606
# Greedy: black and white dog is running through the grass
# bleu_score: 0.7598356856515925
# bleu_score: 0.7598356856515925
# bleu_score: 0.7598356856515925
# bleu_score: 0.7538286083107645
# bleu_score: 0.745169583583891
# Greedy: brown dog is running through the grass
# bleu_score: 0.7790872728179328
# bleu_score: 0.7790872728179328
# bleu_score: 0.7744078583391609
# bleu_score: 0.7720359840572651
# bleu_score: 0.7706022991638174
# Greedy: two dogs are playing in the water
# bleu_score: 0.8070557274927981
# bleu_score: 0.8070557274927981
# bleu_score: 0.8022083267096408
# bleu_score: 0.7997513045108656
# bleu_score: 0.8012282291843922
# Greedy: white dog is running through the grass
# bleu_score: 0.7647860170437231
# bleu_score: 0.7573237977750366
# bleu_score: 0.749634235443537
# bleu_score: 0.749634235443537
# bleu_score: 0.752738377346319
# Greedy: two dogs are sitting on the street
# bleu_score: 0.7541859578343534
# bleu_score: 0.7626139246288385
# bleu_score: 0.7653621274462215
# bleu_score: 0.7667251998579774
# bleu_score: 0.7675395665924378
# Greedy: child in pink shirt is swinging on swing
# bleu_score: 0.7241577342575828
# bleu_score: 0.7241577342575828
# bleu_score: 0.7241577342575828
# bleu_score: 0.7361977212114759
# bleu_score: 0.7400828044922853
# Greedy: boy in red shirt is jumping over railing
# bleu_score: 0.7241577342575828
# bleu_score: 0.7550415303475492
# bleu_score: 0.7645407753841558
# bleu_score: 0.7586456496026764
# bleu_score: 0.7663987253535437
# Greedy: two people are walking through the snow
# bleu_score: 0.7287557921168066
# bleu_score: 0.7368995788758251
# bleu_score: 0.7395551158826803
# bleu_score: 0.7408722272725479
# bleu_score: 0.7478660283017551
# Greedy: man in red shirt is riding on the beach
# bleu_score: 0.7115965735877551
# bleu_score: 0.7287557921168066
# bleu_score: 0.7395551158826803
# bleu_score: 0.7486311096379878
# bleu_score: 0.7478660283017551
# Greedy: woman in red shirt is standing in front of crowd
# bleu_score: 0.7213989879855205
# bleu_score: 0.7143601074246999
# bleu_score: 0.7213989879855205
# bleu_score: 0.7248425177500768
# bleu_score: 0.726885306958105
# Greedy: two dogs are playing on the grass
# bleu_score: 0.8070557274927981
# bleu_score: 0.7997513045108656
# bleu_score: 0.8022083267096408
# bleu_score: 0.7997513045108656
# bleu_score: 0.8012282291843922
# Greedy: black and white dog is running through the water
# bleu_score: 0.7598356856515925
# bleu_score: 0.7598356856515925
# bleu_score: 0.7476743906106103
# bleu_score: 0.7348889200874658
# bleu_score: 0.7426392598423162
# Greedy: dog runs through the grass
# bleu_score: 0.8065008590125561
# bleu_score: 0.8065008590125561
# bleu_score: 0.8065008590125561
# bleu_score: 0.801878887299181
# bleu_score: 0.7990668782917915
# Greedy: two dogs are running through the grass
# bleu_score: 0.7647860170437231
# bleu_score: 0.7573237977750366
# bleu_score: 0.749634235443537
# bleu_score: 0.7535084431893706
# bleu_score: 0.752738377346319
# Greedy: two children are playing in the water
# bleu_score: 0.7699019277569183
# bleu_score: 0.7623897911954858
# bleu_score: 0.7699019277569183
# bleu_score: 0.7699019277569183
# bleu_score: 0.7699019277569183
# Greedy: man in white shirt and white shirt is standing on the sidewalk
# bleu_score: 0.6766871285089037
# bleu_score: 0.6893409630302637
# bleu_score: 0.6852005898066748
# bleu_score: 0.6831019416080527
# bleu_score: 0.6843634464113638
# Greedy: two dogs are playing in the water
# bleu_score: 0.7765453555044466
# bleu_score: 0.7845109654406773
# bleu_score: 0.7871130275822675
# bleu_score: 0.7884044396805875
# bleu_score: 0.7891762511183534
# Greedy: man in red shirt and black shirt and black hat and black hat
# bleu_score: 0.668740304976422
# bleu_score: 0.6822570396306888
# bleu_score: 0.6865890479690392
# bleu_score: 0.6822570396306888
# bleu_score: 0.6769472427712399
# Greedy: black dog is running through the grass
# bleu_score: 0.7926416986492341
# bleu_score: 0.799166048865006
# bleu_score: 0.7970090358120312
# bleu_score: 0.7825422900366437
# bleu_score: 0.7845935325065408
# Greedy: man in red shirt is standing on rock
# bleu_score: 0.7751936613371729
# bleu_score: 0.7825422900366437
# bleu_score: 0.7801157731069053
# bleu_score: 0.7714395865600262
# bleu_score: 0.7751936613371729
# Greedy: two children are sitting on the floor
# bleu_score: 0.7546487907970829
# bleu_score: 0.7546487907970829
# bleu_score: 0.7546487907970829
# bleu_score: 0.7623897911954858
# bleu_score: 0.7669235279185573
# Greedy: group of people are standing on the beach
# bleu_score: 0.7644270467420534
# bleu_score: 0.757508443356907
# bleu_score: 0.7644270467420534
# bleu_score: 0.7644270467420534
# bleu_score: 0.7671426385150502
# Greedy: group of people are standing on the street
# bleu_score: 0.7458878201607712
# bleu_score: 0.7598356856515925
# bleu_score: 0.7598356856515925
# bleu_score: 0.7529586373193689
# bleu_score: 0.7571073267517036
# Greedy: man is climbing rock
# bleu_score: 0.861173529963367
# bleu_score: 0.8707970741827025
# bleu_score: 0.8739351325046805
# bleu_score: 0.8754915681134768
# bleu_score: 0.8726839694794392
# Greedy: boy in red shirt is running through grassy field
# bleu_score: 0.7348889200874658
# bleu_score: 0.7348889200874658
# bleu_score: 0.7348889200874658
# bleu_score: 0.7282376575609851
# bleu_score: 0.7322501380936575
# Greedy: man in the ocean
# bleu_score: 0.8408964152537145
# bleu_score: 0.8537382425870722
# bleu_score: 0.8578928092681435
# bleu_score: 0.8537382425870722
# bleu_score: 0.8512160931922469
# Greedy: man in wetsuit is surfing on the ocean
# bleu_score: 0.7926416986492341
# bleu_score: 0.7859521411137845
# bleu_score: 0.7836838573162302
# bleu_score: 0.7790872728179328
# bleu_score: 0.7790872728179328
# Greedy: man wearing black hat and black jacket and black jacket and black jacket and black jacket and black jacket and black jacket and black jacket and black jacket
# bleu_score: 0.5559655755862645
# bleu_score: 0.5512734634857382
# bleu_score: 0.5528507999574939
# bleu_score: 0.5512734634857382
# bleu_score: 0.548399655116122
# Greedy: boy in white shirt is standing on the sidewalk
# bleu_score: 0.7556720457448196
# bleu_score: 0.7492944962964933
# bleu_score: 0.7556720457448196
# bleu_score: 0.7556720457448196
# bleu_score: 0.7531404455270682
# Greedy: man in red shirt is sitting on the edge of the water
# bleu_score: 0.7071067811865476
# bleu_score: 0.7138099644618784
# bleu_score: 0.7115965735877551
# bleu_score: 0.7104820884551853
# bleu_score: 0.7098108717509044
# Greedy: man in red shirt and backpack is sitting on the top of the mountains
# bleu_score: 0.6853234406569368
# bleu_score: 0.6964705665515708
# bleu_score: 0.7000700175052517
# bleu_score: 0.6964705665515708
# bleu_score: 0.6964705665515708
# Greedy: two black dogs are running on the grass
# bleu_score: 0.8003203203844999
# bleu_score: 0.8003203203844999
# bleu_score: 0.8044564804446751
# bleu_score: 0.8065008590125561
# bleu_score: 0.8003203203844999
# Greedy: boy in jeans is walking on the sidewalk
# bleu_score: 0.7287557921168066
# bleu_score: 0.7524217680744609
# bleu_score: 0.7598356856515925
# bleu_score: 0.7561559858236034
# bleu_score: 0.7539221180326289
# Greedy: two boys playing on the grass
# bleu_score: 0.8480536257973762
# bleu_score: 0.8408964152537145
# bleu_score: 0.8384695604690982
# bleu_score: 0.8335516383402117
# bleu_score: 0.836512792031845
# Greedy: group of children are sitting on bench
# bleu_score: 0.7926416986492341
# bleu_score: 0.8055344092731546
# bleu_score: 0.7926416986492341
# bleu_score: 0.799166048865006
# bleu_score: 0.7952707287670506
# Greedy: man in red shirt and helmet rides bike
# bleu_score: 0.7647860170437231
# bleu_score: 0.7573237977750366
# bleu_score: 0.7598356856515925
# bleu_score: 0.7610823439621528
# bleu_score: 0.7588339225169337
# Greedy: boy is jumping over bridge
# bleu_score: 0.8065008590125561
# bleu_score: 0.8065008590125561
# bleu_score: 0.8003203203844999
# bleu_score: 0.7971755824799469
# bleu_score: 0.7914194256246622
# Greedy: man in black jacket and black hat and black hat and black hat and black hat and black hat and black hat
# bleu_score: 0.5716613954626187
# bleu_score: 0.5716613954626187
# bleu_score: 0.5716613954626187
# bleu_score: 0.5716613954626187
# bleu_score: 0.5690450275088251
# Greedy: man in black shirt is standing on rock
# bleu_score: 0.749634235443537
# bleu_score: 0.7647860170437231
# bleu_score: 0.769642045212638
# bleu_score: 0.7720359840572651
# bleu_score: 0.7762897868157319
# Greedy: man in black jacket and hat stands on sidewalk
# bleu_score: 0.7291155827927387
# bleu_score: 0.7360274036243225
# bleu_score: 0.7337451206367
# bleu_score: 0.732595946991973
# bleu_score: 0.7346605873210277
# Greedy: man in red hat and hat is walking down street
# bleu_score: 0.7468422531048421
# bleu_score: 0.7400828044922853
# bleu_score: 0.7377879464668811
# bleu_score: 0.7400828044922853
# bleu_score: 0.7441605500122526
# Greedy: man in red shirt and helmet is riding bike
# bleu_score: 0.7598356856515925
# bleu_score: 0.7529586373193689
# bleu_score: 0.7458878201607712
# bleu_score: 0.7458878201607712
# bleu_score: 0.7487402156832422
# Greedy: man wearing hat and hat is standing on the street
# bleu_score: 0.7034711503007025
# bleu_score: 0.6960259633460557
# bleu_score: 0.6985342056580097
# bleu_score: 0.6997782608186398
# bleu_score: 0.7034711503007025
# Greedy: two boys are standing on the sidewalk
# bleu_score: 0.7842988494376653
# bleu_score: 0.7979439453790055
# bleu_score: 0.80234049712795
# bleu_score: 0.8012481317672601
# bleu_score: 0.8005905619628992
# Greedy: man in black shirt and black hat is standing on the camera
# bleu_score: 0.724724590060866
# bleu_score: 0.7189950925583076
# bleu_score: 0.7209201301126734
# bleu_score: 0.7218768941687622
# bleu_score: 0.7178326067961881
# Greedy: black dog is jumping in the water
# bleu_score: 0.8210967436686386
# bleu_score: 0.8408964152537145
# bleu_score: 0.851318433571997
# bleu_score: 0.8563890474679646
# bleu_score: 0.8521358309931549
# Greedy: man is jumping over the air
# bleu_score: 0.8329997998131278
# bleu_score: 0.8408964152537145
# bleu_score: 0.8434798448117476
# bleu_score: 0.8289657839357887
# bleu_score: 0.8232172841824639
# Greedy: two people are walking along the beach
# bleu_score: 0.7647860170437231
# bleu_score: 0.7647860170437231
# bleu_score: 0.7598356856515925
# bleu_score: 0.7573237977750366
# bleu_score: 0.761827408333416
# Greedy: dog is walking through the water
# bleu_score: 0.798359216893685
# bleu_score: 0.7905694150420948
# bleu_score: 0.8034284189446518
# bleu_score: 0.8096329601160915
# bleu_score: 0.8074157792118413
# Greedy: man in blue shirt is sitting on the edge of the water
# bleu_score: 0.7169073641343396
# bleu_score: 0.7232243388903353
# bleu_score: 0.7293799946522604
# bleu_score: 0.7263217302612206
# bleu_score: 0.7219741624986888
# Greedy: man is standing on the edge of the water
# bleu_score: 0.7241577342575828
# bleu_score: 0.7400828044922853
# bleu_score: 0.7400828044922853
# bleu_score: 0.7476743906106103
# bleu_score: 0.7461745347323253
# Greedy: man is sitting on the water
# bleu_score: 0.7801157731069053
# bleu_score: 0.7801157731069053
# bleu_score: 0.7865370205901889
# bleu_score: 0.7896895367562644
# bleu_score: 0.7915630719552208
# Greedy: little girl in pink shirt is standing on the sidewalk
# bleu_score: 0.7037475090852178
# bleu_score: 0.7037475090852178
# bleu_score: 0.6991922696996642
# bleu_score: 0.6968808586685619
# bleu_score: 0.701025030556799
# Greedy: two dogs are running through the grass
# bleu_score: 0.7162326270441588
# bleu_score: 0.733503637924837
# bleu_score: 0.744373319312051
# bleu_score: 0.7456990116859172
# bleu_score: 0.7433076425364417
# Greedy: man in hat hat and hat hat
# bleu_score: 0.7203294535577252
# bleu_score: 0.7203294535577252
# bleu_score: 0.7203294535577252
# bleu_score: 0.7138099644618784
# bleu_score: 0.7098108717509044
# Greedy: baby is eating
# bleu_score: 0.8694417438899827
# bleu_score: 0.8827195038481814
# bleu_score: 0.887015102729059
# bleu_score: 0.8761560783209453
# bleu_score: 0.8801117367933934
# Greedy: child in red jacket is sitting on the snow
# bleu_score: 0.7598356856515925
# bleu_score: 0.7529586373193689
# bleu_score: 0.7506238537503395
# bleu_score: 0.7529586373193689
# bleu_score: 0.7487402156832422
# Greedy: two dogs are running through the snow
# bleu_score: 0.7546487907970829
# bleu_score: 0.7623897911954858
# bleu_score: 0.7649184819342956
# bleu_score: 0.7623897911954858
# bleu_score: 0.7639100176693358
# Greedy: boy in pink shirt is walking down the street
# bleu_score: 0.7510499815709779
# bleu_score: 0.7510499815709779
# bleu_score: 0.7510499815709779
# bleu_score: 0.7543806618541438
# bleu_score: 0.7537180519378702
# Greedy: boy in blue shirt is walking on the beach
# bleu_score: 0.7777264164917724
# bleu_score: 0.7644270467420534
# bleu_score: 0.7777264164917724
# bleu_score: 0.7744654372724812
# bleu_score: 0.7724889036677813
# Greedy: man in red shirt and jeans is sitting on bench
# bleu_score: 0.7146704964214272
# bleu_score: 0.7220014093772165
# bleu_score: 0.7195826101964229
# bleu_score: 0.7183640069923742
# bleu_score: 0.7205530542221067
# Greedy: two dogs are playing in the snow
# bleu_score: 0.8274377299117183
# bleu_score: 0.8204545087278228
# bleu_score: 0.8084034456197733
# bleu_score: 0.8132882808488929
# bleu_score: 0.8103679885263144
# Greedy: boy is playing with his head
# bleu_score: 0.8254605646966103
# bleu_score: 0.8408964152537145
# bleu_score: 0.8458576712796905
# bleu_score: 0.8446255373883188
# bleu_score: 0.8438836609260618
# Greedy: black dog is running through the grass
# bleu_score: 0.8055344092731546
# bleu_score: 0.799166048865006
# bleu_score: 0.7926416986492341
# bleu_score: 0.7959239290948774
# bleu_score: 0.7926416986492341

# %%
print("mean of arr : ", np.mean(beluscores))
# Out:
# mean of arr :  0.7588578817586583

# %% [markdown]
# # Beam Search

# %%
"Beam Search, inspired by the example provided but tailor-made for our model"

import tensorflow as tf
import numpy as np
# import data


class Hypothesis(object):
    """Class to represent a hypothesis during beam search. Holds all the information needed for the hypothesis."""

    def __init__(self, tokens, log_probs):
        self.tokens = tokens
        self.log_probs = log_probs

    def extend(self, token, log_prob):
        """Return a NEW hypothesis, extended with the information from the latest step of beam search.

        Args:
        token: Integer. Latest token produced by beam search.
        log_prob: Float. Log prob of the latest token.
        state: Current decoder state, a LSTMStateTuple.
        Returns:
        New Hypothesis for next step.
        """
        return Hypothesis(tokens = self.tokens + [token],
        log_probs = self.log_probs + [log_prob])

    @property
    def get_tokens(self):
        return self.tokens

    @property
    def latest_token(self):
        return self.tokens[-1]

    @property
    def log_prob(self):
    # the log probability of the hypothesis so far is the sum of the log probabilities of the tokens so far
        return sum(self.log_probs)

    @property
    def avg_log_prob(self):
    # normalize log probability by number of tokens (otherwise longer sequences always have lower probability)
        return self.log_prob / len(self.tokens)


def decode_one_step(cap_inputs, img_feats, decoder_model, len_hyps, beam_size, words_indices, indices_words):

    topk_probs = []
    topk_ids = []

    for i in range(len_hyps):

        cap_input = cap_inputs[i]
        img_feat = img_feats[i]
#         print(cap_input)
        
        pred_prob_t = decoder_model.predict([img_feat, cap_input] , verbose = 0)

        topk_prob = np.sort(pred_prob_t[0], axis=-1)[-(beam_size):][::-1]

        topk_logprob = -np.log(topk_prob)

        topk_id = np.argsort(pred_prob_t[0], axis=-1)[-(beam_size):][::-1]

        topk_probs.append(topk_logprob)
        topk_ids.append(topk_id)

    return topk_probs, topk_ids

def run_beam_search(encoding, decoder_model, words_indices, indices_words, \
      min_dec_steps, max_dec_steps, num_hyps, beam_size):

    #beam search decoding 
    encoder_output = encoding
    # Initialize beam_size-many hypotheses
    hyps = [Hypothesis(tokens=[words_indices.get('startseq')],
    log_probs=[0.0]                      
                     # zero vector of length attention_length
                     ) for _ in range(num_hyps)]

    results = [] # this will contain finished hypotheses (those that have emitted the [STOP] token)

    steps = 0
    while steps < max_dec_steps and len(results) < beam_size:

        hyp_tokens = [h.get_tokens for h in hyps] # latest token produced by each hypothesis

        len_hyps = len(hyp_tokens)

        img_feats = np.array([encoder_output] * len_hyps)

        dec_inputs = []
#         dec_inputs = hyp_tokens
        for dec_input in hyp_tokens:
            dec_inputs.append(pad_sequences([dec_input], maxlen=max_length))
    # dec_inputs = np.array(dec_inputs)
    # dec_inputs = np.reshape(dec_inputs, (dec_inputs.shape[0], 1))


    # Run one step of the decoder to get the new info
        topk_log_probs, topk_ids = decode_one_step(
          dec_inputs, img_feats, decoder_model, len_hyps, beam_size, words_indices, indices_words)

        topk_log_probs = np.array(topk_log_probs)
        topk_ids = np.array(topk_ids)


    # Extend each hypothesis and collect them all in all_hyps
        all_hyps = []
        num_orig_hyps = 1 if steps == 0 else len(hyps) # On the first step, we only had one original hypothesis (the initial hypothesis). 
                                                       # On subsequent steps, all original hypotheses are distinct.
        for i in range(num_orig_hyps):
            h = hyps[i]  # take the ith hypothesis and new decoder state info
            for j in range(beam_size):  # for each of the top 2*beam_size hyps:
            # Extend the ith hypothesis with the jth option

                logprobs= np.array(topk_log_probs[i,j])
                new_hyp = h.extend(token=topk_ids[i,j], log_prob=logprobs)
                all_hyps.append(new_hyp)

        # Filter and collect any hypotheses that have produced the end token.
        hyps = [] # will contain hypotheses for the next step

        for h in sort_hyps(all_hyps): # in order of most likely h
            if h.latest_token == words_indices.get('endseq'): # if stop token is reached...
        # If this hypothesis is sufficiently long, put in results. Otherwise discard.
                if steps >= min_dec_steps:
                    results.append(h)
            else: # hasn't reached stop token, so continue to extend this hypothesis
                hyps.append(h)
            if len(hyps) == beam_size or len(results) == beam_size:
        # Once we've collected beam_size-many hypotheses for the next step, or beam_size-many complete hypotheses, stop.
                break

        steps += 1

    # At this point, either we've got beam_size results, or we've reached maximum decoder steps

    if len(results)==0: # if we don't have any complete results, add all current hypotheses (incomplete summaries) to results
        results = hyps

    # Sort hypotheses by average log probability
    hyps_sorted = sort_hyps(results)
    
    # Return the hypothesis with highest average log prob
    translated_hyps = get_string_from_hypothesis(hyps_sorted)
    return translated_hyps

def sort_hyps(hyps):
    """Return a list of Hypothesis objects, sorted by average log probability"""
    return sorted(hyps, key=lambda h: h.avg_log_prob, reverse=False)

def get_string_from_hypothesis(sorted_hyps):
    stringHyps = []
    for hypothesis in sorted_hyps:
        
        stringHyp = ''
        for token in hypothesis.tokens:
            stringHyp += ' ' + ixtoword[token]
            
        stringHyps.append(stringHyp)    
        
    return stringHyps

# %%
pic = list(encoding_test.keys())[14]
image = encoding_test[pic].reshape((1,2048))
# x=plt.imread(os.getcwd() + '\\data\\Flicker8k_Dataset\\'+pic)
x=plt.imread(images+pic)
plt.imshow(x)
plt.show()
run_beam_search(image, model, wordtoix, ixtoword, 3, 32, 1, 5)
# Out:
# [' startseq two children are playing in the snow endseq',
#  ' startseq two children play in the snow endseq',
#  ' startseq little boy in red shirt is standing in the snow endseq',
#  ' startseq two children are playing in the water endseq',
#  ' startseq two children are playing on the snow endseq']

# %% [markdown]
# # Video Images Captioning

# %%
import csv

def write_csvtotext(filename):
  
  output=open(folderName+'/'+'flickr8k_video.token.txt','w')

  with open(filename,"rt", encoding='utf-8') as f:
      f.readline()
      lines = [line.replace('|', '').strip() + '\n' for line in f.readlines()]
      for l in lines:
          output.write(l)
  output.close()

# %%
folderName='/content/drive/My Drive/App/storage/TomAndJerry'
imageDir=folderName+'/Images'
filename = folderName+'/'+'test-video.csv'
# write description
write_csvtotext(filename)

# %%
#max_length = 21
print('Description Length: %d' % max_length)
# load the model
filename = folderName+'/model_30.h5'
print("filename:",filename)
model = load_model(filename)
# load and prepare the photograph
folderName='/content/drive/My Drive/App/storage/TomAndJerry'
imageDir=folderName+'/Images'
imageFileName = imageDir+'/'+'image0.jpg'
print("imageFileName:", imageFileName)
photo = extract_features(imageFileName)

caption = generate_desc(model, tokenizer, photo, max_length) 
print(caption)
